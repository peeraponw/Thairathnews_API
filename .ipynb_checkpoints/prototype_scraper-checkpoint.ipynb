# %% [markdown]
# # Import Libraries

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver

# %% [markdown]
# Set URL and define Selenium webdriver. In this case, bs4 is unable to retrieve information from Javascript website. Please note that the Chrome webdriver should be the same version as Chrome that is installed in your machine. The webdriver itself can be downloaded from Google website.

# %%
url = 'https://www.thairath.co.th/news/business'
driver = webdriver.Chrome('C:\Program Files\Google\chromedriver.exe')
driver.get(url)

# %% [markdown]
# Response 200 = OK!

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')

driver.close() # do not forget to close the webdriver
print(soup.prettify())
# Out:
# <html lang="th">
#  <head>
#   <meta charset="utf-8"/>
#   <link data-react-helmet="true" href="https://www.thairath.co.th/news/business" rel="canonical"/>
#   <link data-react-helmet="true" href="https://www.thairath.co.th/assets/images/thairath_logo2.jpg" rel="image_src"/>
#   <meta content="ข่าวเศรษฐกิจ ราคาหุ้น ทอง น้ำมัน อสังหาฯ การเงิน | ไทยรัฐออนไลน์" data-react-helmet="true" property="og:title"/>
#   <meta content="https://www.thairath.co.th/news/business" data-react-helmet="true" property="og:url"/>
#   <meta content="ข่าวหุ้น ข่าวเศรษฐกิจวันนี้ ข่าวเศรษฐกิจล่าสุด AEC เศรษฐกิจโลก เศรษฐกิจไทย วิเคราะห์แนวโน้มเศรษฐกิจ การเงิน ทิศทางการลงทุน เช็คราคาหุ้น ทอง น้ำมัน อสังหาริมทรัพย์ โดยทีมข่าวเศรษฐกิจไทยรัฐออนไลน์" data-react-helmet="true" property="og:description"/>
#   <meta content="https://www.thairath.co.th/assets/images/thairath_logo2.jpg" data-react-helmet="true" property="og:image"/>
#   <meta content="frontpage" data-react-helmet="true" name="cXenseParse:pageclass"/>
#   <meta content="หุ้น, ข่าวหุ้น, ข่าวเศรษฐกิจ, ข่าวเศรษฐกิจไทยรัฐ" data-react-helmet="true" name="keywords"/>
#   <meta content="ข่าวหุ้น ข่าวเศรษฐกิจวันนี้ ข่าวเศรษฐกิจล่าสุด AEC เศรษฐกิจโลก เศรษฐกิจไทย วิเคราะห์แนวโน้มเศรษฐกิจ การเงิน ทิศทางการลงทุน เช็คราคาหุ้น ทอง น้ำมัน อสังหาริมทรัพย์ โดยทีมข่าวเศรษฐกิจไทยรัฐออนไลน์" data-react-helmet="true" name="description"/>
#   <meta content="https://www.thairath.co.th/assets/images/thairath_logo2.jpg" data-react-helmet="true" name="twitter:image"/>
#   <meta content="https://www.thairath.co.th/news/business" data-react-helmet="true" name="twitter:site"/>
#   <meta content="article" data-react-helmet="true" name="cXenseParse:trt-mediatype"/>
#   <meta content="news" data-react-helmet="true" name="cXenseParse:trt-contentsection"/>
#   <meta content="business" data-react-helmet="true" name="cXenseParse:trt-contenttopic"/>
#   <meta content="https://www.thairath.co.th" name="webiste-url"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="Thairath" name="apple-mobile-web-app-title"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="#424242" name="msapplication-TileColor"/>
#   <meta content="/static/img/favicon/ms-icon-144x144.png" name="msapplication-TileImage"/>
#   <meta content="#424242" name="theme-color"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="630" property="og:image:height"/>
#   <meta content="www.thairath.co.th" property="og:site_name"/>
#   <meta content="639717687" property="fb:admins"/>
#   <meta content="546617158831626" property="fb:app_id"/>
#   <meta content="article" property="og:type"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <link href="/static/img/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/static/img/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="/static/img/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/static/img/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/static/img/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/static/img/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/static/img/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="/static/img/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/static/img/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/static/img/favicon/favicon-32x32.png" rel="icon" type="image/x-icon"/>
#   <link href="/static/img/favicon/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="/static/img/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/static/img/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="/static/img/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/static/json/manifest.json" rel="manifest"/>
#   <link href="//lvs2.truehits.in.th" rel="preconnect"/>
#   <link href="//player.h-cdn.com" rel="preconnect"/>
#   <link href="//perr.h-cdn.com" rel="preconnect"/>
#   <link href="//facebook.com" rel="preconnect"/>
#   <link href="//staticxx.facebook.com" rel="preconnect"/>
#   <link href="//i.liadm.com" rel="preconnect"/>
#   <link href="//loadm.exelator.com" rel="preconnect"/>
#   <link href="//pxl.connexity.net" rel="preconnect"/>
#   <link href="//d.agkn.com" rel="preconnect"/>
#   <link href="//aa.agkn.com" rel="preconnect"/>
#   <link href="//idsync.rlcdn.com" rel="preconnect"/>
#   <link href="//pippio.com" rel="preconnect"/>
#   <link href="//sync.crwdcntrl.net" rel="preconnect"/>
#   <link href="//ml314.com" rel="preconnect"/>
#   <link href="//load77.exelator.com" rel="preconnect"/>
#   <link href="//tags.rd.linksynergy.com" rel="preconnect"/>
#   <link href="//fonts.googleapis.com" rel="preconnect"/>
#   <link href="//fonts.gstatic.com" rel="preconnect"/>
#   <link href="//google-analytics.com" rel="preconnect"/>
#   <link href="//p1cluster.cxense.com" rel="preconnect"/>
#   <link href="//comcluster.cxense.com" rel="preconnect"/>
#   <link href="//api.cxense.com" rel="preconnect"/>
#   <link href="//tpc.googlesyndication.com" rel="preconnect"/>
#   <link href="https://scomcluster.cxense.com" rel="preconnect"/>
#   <link href="https://scdn.cxense.com" rel="preconnect"/>
#   <link href="https://www.googletagservices.com" rel="preconnect"/>
#   <link href="https://connect.facebook.net" rel="preconnect"/>
#   <link href="https://id.cxense.com" rel="preconnect"/>
#   <link href="https://cdn.cxense.com" rel="preconnect"/>
#   <link href="http://api.popin.cc/searchbox/thairath_th.js" rel="preconnect"/>
#   <link href="https://ad.doubleclick.net" rel="preconnect"/>
#   <link href="https://sp1cluster.cxense.com" rel="preconnect"/>
#   <link as="font" href="/static/font/Cloud-LightBold/cloud-regular-webfont.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" href="/static/font/Cloud-LightBold/cloud-semibold-webfont.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" href="/static/font/MN_by_DB/MN%20Paethai%20v3.2.1.ttf" rel="preload" type="font/ttf"/>
#   <link as="font" href="/static/font/MN_by_DB/MN%20Paethai%20Med%20v3.2.1.ttf" rel="preload" type="font/ttf"/>
#   <link href="https://tags.adnuntius.com/pb/thairath/thairath.co.th/desktop.js" rel="preload"/>
#   <link href="https://tags.adnuntius.com/pb/thairath/thairath.co.th/mobile.js" rel="preload"/>
#   <style>
#   </style>
#   <style>
#    .container{width:100%;padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}@media (min-width:576px){.container{max-width:540px}}@media (min-width:768px){.container{max-width:720px}}@media (min-width:992px){.container{max-width:960px}}@media (min-width:1200px){.container{max-width:1140px}}.container-fluid{width:100%;padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}.row{display:flex;flex-wrap:wrap;margin-right:-15px;margin-left:-15px}.no-gutters{margin-right:0;margin-left:0}.no-gutters>.col,.no-gutters>[class*=col-]{padding-right:0;padding-left:0}.col,.col-1,.col-2,.col-3,.col-4,.col-5,.col-6,.col-7,.col-8,.col-9,.col-10,.col-11,.col-12,.col-auto,.col-lg,.col-lg-1,.col-lg-2,.col-lg-3,.col-lg-4,.col-lg-5,.col-lg-6,.col-lg-7,.col-lg-8,.col-lg-9,.col-lg-10,.col-lg-11,.col-lg-12,.col-lg-auto,.col-md,.col-md-1,.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9,.col-md-10,.col-md-11,.col-md-12,.col-md-auto,.col-sm,.col-sm-1,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9,.col-sm-10,.col-sm-11,.col-sm-12,.col-sm-auto,.col-xl,.col-xl-1,.col-xl-2,.col-xl-3,.col-xl-4,.col-xl-5,.col-xl-6,.col-xl-7,.col-xl-8,.col-xl-9,.col-xl-10,.col-xl-11,.col-xl-12,.col-xl-auto{position:relative;width:100%;padding-right:15px;padding-left:15px}.col{flex-basis:0;flex-grow:1;max-width:100%}.col-auto{flex:0 0 auto;width:auto;max-width:100%}.col-1{flex:0 0 8.33333%;max-width:8.33333%}.col-2{flex:0 0 16.66667%;max-width:16.66667%}.col-3{flex:0 0 25%;max-width:25%}.col-4{flex:0 0 33.33333%;max-width:33.33333%}.col-5{flex:0 0 41.66667%;max-width:41.66667%}.col-6{flex:0 0 50%;max-width:50%}.col-7{flex:0 0 58.33333%;max-width:58.33333%}.col-8{flex:0 0 66.66667%;max-width:66.66667%}.col-9{flex:0 0 75%;max-width:75%}.col-10{flex:0 0 83.33333%;max-width:83.33333%}.col-11{flex:0 0 91.66667%;max-width:91.66667%}.col-12{flex:0 0 100%;max-width:100%}.order-first{order:-1}.order-last{order:13}.order-0{order:0}.order-1{order:1}.order-2{order:2}.order-3{order:3}.order-4{order:4}.order-5{order:5}.order-6{order:6}.order-7{order:7}.order-8{order:8}.order-9{order:9}.order-10{order:10}.order-11{order:11}.order-12{order:12}.offset-1{margin-left:8.33333%}.offset-2{margin-left:16.66667%}.offset-3{margin-left:25%}.offset-4{margin-left:33.33333%}.offset-5{margin-left:41.66667%}.offset-6{margin-left:50%}.offset-7{margin-left:58.33333%}.offset-8{margin-left:66.66667%}.offset-9{margin-left:75%}.offset-10{margin-left:83.33333%}.offset-11{margin-left:91.66667%}@media (min-width:576px){.col-sm{flex-basis:0;flex-grow:1;max-width:100%}.col-sm-auto{flex:0 0 auto;width:auto;max-width:100%}.col-sm-1{flex:0 0 8.33333%;max-width:8.33333%}.col-sm-2{flex:0 0 16.66667%;max-width:16.66667%}.col-sm-3{flex:0 0 25%;max-width:25%}.col-sm-4{flex:0 0 33.33333%;max-width:33.33333%}.col-sm-5{flex:0 0 41.66667%;max-width:41.66667%}.col-sm-6{flex:0 0 50%;max-width:50%}.col-sm-7{flex:0 0 58.33333%;max-width:58.33333%}.col-sm-8{flex:0 0 66.66667%;max-width:66.66667%}.col-sm-9{flex:0 0 75%;max-width:75%}.col-sm-10{flex:0 0 83.33333%;max-width:83.33333%}.col-sm-11{flex:0 0 91.66667%;max-width:91.66667%}.col-sm-12{flex:0 0 100%;max-width:100%}.order-sm-first{order:-1}.order-sm-last{order:13}.order-sm-0{order:0}.order-sm-1{order:1}.order-sm-2{order:2}.order-sm-3{order:3}.order-sm-4{order:4}.order-sm-5{order:5}.order-sm-6{order:6}.order-sm-7{order:7}.order-sm-8{order:8}.order-sm-9{order:9}.order-sm-10{order:10}.order-sm-11{order:11}.order-sm-12{order:12}.offset-sm-0{margin-left:0}.offset-sm-1{margin-left:8.33333%}.offset-sm-2{margin-left:16.66667%}.offset-sm-3{margin-left:25%}.offset-sm-4{margin-left:33.33333%}.offset-sm-5{margin-left:41.66667%}.offset-sm-6{margin-left:50%}.offset-sm-7{margin-left:58.33333%}.offset-sm-8{margin-left:66.66667%}.offset-sm-9{margin-left:75%}.offset-sm-10{margin-left:83.33333%}.offset-sm-11{margin-left:91.66667%}}@media (min-width:768px){.col-md{flex-basis:0;flex-grow:1;max-width:100%} ...
#   </style>
#   <style>
#    #nprogress{pointer-events:none}#nprogress .bar{background:#29d;position:fixed;z-index:1031;top:0;left:0;width:100%;height:2px}#nprogress .peg{display:block;position:absolute;right:0;width:100px;height:100%;box-shadow:0 0 10px #29d,0 0 5px #29d;opacity:1;transform:rotate(3deg) translateY(-4px)}#nprogress .spinner{display:block;position:fixed;z-index:1031;top:15px;right:15px}#nprogress .spinner-icon{width:18px;height:18px;box-sizing:border-box;border-color:#29d transparent transparent #29d;border-style:solid;border-width:2px;border-radius:50%;-webkit-animation:nprogress-spinner .4s linear infinite;animation:nprogress-spinner .4s linear infinite}.nprogress-custom-parent{overflow:hidden;position:relative}.nprogress-custom-parent #nprogress .bar,.nprogress-custom-parent #nprogress .spinner{position:absolute}@-webkit-keyframes nprogress-spinner{0%{-webkit-transform:rotate(0deg)}to{-webkit-transform:rotate(1turn)}}@keyframes nprogress-spinner{0%{transform:rotate(0deg)}to{transform:rotate(1turn)}}
#   </style>
#   <style>
#    *{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;-webkit-overflow-scrolling:touch}*,:after,:before{box-sizing:border-box}body{padding:170px 0 0;margin:0;letter-spacing:.2px;color:#292929}@font-face{font-display:swap;font-family:DB ComYard X;src:url(/static/font/DBComYardX/subset-DBComYardX-Bold.eot);src:url(/static/font/DBComYardX/subset-DBComYardX-Bold.eot?#iefix) format("embedded-opentype"),url(/static/font/DBComYardX/subset-DBComYardX-Bold.woff2) format("woff2"),url(/static/font/DBComYardX/subset-DBComYardX-Bold.woff) format("woff"),url(/static/font/DBComYardX/subset-DBComYardX-Bold.ttf) format("truetype"),url(/static/font/DBComYardX/subset-DBComYardX-Bold.svg#DBComYardX-Bold) format("svg");font-weight:700;font-style:normal}h1,h2,h3,h4,h5,h6{margin-top:0;margin-bottom:.5rem;font-family:inherit;line-height:1.2;color:inherit;font-weight:400;-webkit-font-smoothing:auto}h1{font-size:2rem}h4{color:#333;font-weight:300;line-height:1.5}a{background-color:transparent;color:#01b400}a,a:hover{text-decoration:none}a:hover{color:#999}.text-center{text-align:center}.hidden{display:none!important}dl,ol{margin-top:0;margin-bottom:1rem}ol.alignleft{text-align:left;font-size:.85rem}ol.alignleft li{margin-bottom:.5rem}.true-hits{position:absolute;margin:0 1rem;right:0;z-index:1}@media (max-width:768px){body{padding:0}.true-hits{position:fixed;top:.35rem;right:0;z-index:5;margin:.25rem 1rem}}.line-clamp{display:block;display:-webkit-box;position:relative;line-height:1.4;overflow:hidden;text-overflow:ellipsis;padding:0!important}.line-clamp:after{content:"";text-align:right;bottom:0;right:0;width:25%;display:block;position:absolute;height:1.3em}@supports (-webkit-line-clamp:1){.line-clamp:after{display:none!important}}.line-clamp-1{-webkit-line-clamp:1;height:1.3em}.line-clamp-2{-webkit-line-clamp:2;height:2.6em}.line-clamp-3{-webkit-line-clamp:3;height:3.9em}.line-clamp-4{-webkit-line-clamp:4;height:5.2em}.line-clamp-5{-webkit-line-clamp:5;height:6.5em}.modal-dialog{max-width:420px;margin:0 auto}.rotate,.rotate-y{transition:all .5s linear;transform:rotate(180deg)}.paddingTop1{margin-top:1rem}.paddingTop2{margin-top:2rem}.paddingTop2 h3:first-child{color:#00b400;font-size:1.75rem}.padding-b-3{padding-bottom:3rem}.padding-t-3{padding-top:3rem}
#   </style>
#   <style>
#    @font-face{font-display:swap;font-family:cloudlight;font-style:normal;font-weight:400;src:url(/static/font/Cloud-LightBold/Cloud-Light.otf)}@font-face{font-display:swap;font-family:cloudbold;font-style:normal;font-weight:400;src:url(/static/font/Cloud-LightBold/Cloud-Bold.otf)}@font-face{font-display:swap;font-family:cloudregular;src:url(/static/font/Cloud-LightBold/cloud-regular-webfont.eot);src:url(/static/font/Cloud-LightBold/cloud-regular-webfont.eot?#iefix) format("embedded-opentype"),url(/static/font/Cloud-LightBold/cloud-regular-webfont.woff2) format("woff2"),url(/static/font/Cloud-LightBold/cloud-regular-webfont.woff) format("woff"),url(/static/font/Cloud-LightBold/cloud-regular-webfont.ttf) format("truetype"),url(/static/font/Cloud-LightBold/cloud-regular-webfont.svg#cloudregular) format("svg");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:cloudsemibold;src:url(/static/font/Cloud-LightBold/cloud-semibold-webfont.eot);src:url(/static/font/Cloud-LightBold/cloud-semibold-webfont.eot?#iefix) format("embedded-opentype"),url(/static/font/Cloud-LightBold/cloud-semibold-webfont.woff2) format("woff2"),url(/static/font/Cloud-LightBold/cloud-semibold-webfont.woff) format("woff"),url(/static/font/Cloud-LightBold/cloud-semibold-webfont.ttf) format("truetype"),url(/static/font/Cloud-LightBold/cloud-semibold-webfont.svg#cloudsemibold) format("svg");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Mn paethai v3;src:url("/static/font/MN_by_DB/MN Paethai v3.2.1.ttf") format("truetype");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Mn paethai med v3;src:url("/static/font/MN_by_DB/MN Paethai Med v3.2.1.ttf") format("truetype");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Mn paethai li v3;src:url("/static/font/MN_by_DB/MN Paethai Li v3.2.1.ttf") format("truetype");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Mn paethai demibd v3;src:url("/static/font/MN_by_DB/MN Paethai DemiBd v3.2.1.ttf") format("truetype");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Mn paethai li it v3;src:url("/static/font/MN_by_DB/MN Paethai Li It v3.2.1.ttf") format("truetype");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Mn paethai it v3;src:url("/static/font/MN_by_DB/MN Paethai It v3.2.1.ttf") format("truetype");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Mn paethai bd v3;src:url("/static/font/MN_by_DB/MN Paethai Bd v3.2.1.ttf") format("truetype");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Mn paethai bd it v3;src:url("/static/font/MN_by_DB/MN Paethai Bd It v3.2.1.ttf") format("truetype");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Bodoni-72;src:url(/static/font/Bodoni/BodoniSvtyTwoITCTT-Book.woff2) format("woff2"),url(/static/font/Bodoni/BodoniSvtyTwoITCTT-Book.woff) format("woff");font-weight:400;font-style:normal}
#   </style>
#   <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-WK2N7MN">
#   </script>
#   <script async="" charset="utf-8" src="https://api.popin.cc/searchbox/thairath_th.js" type="text/javascript">
#   </script>
#   <script async="" src="https://cdn.cxense.com/cx.cce.js" type="text/javascript">
#   </script>
#   <script async="">
#    (function(d,s,e,t){e=d.createElement(s);e.type='text/java'+s;e.async='async';e.src='https://cdn.cxense.com/cx.cce.js';t=d.getElementsByTagName(s)[0];t.parentNode.insertBefore(e,t);})(document,'script');
#
#     // datalayer
#     window.dataLayer = window.dataLayer || []
#
#     // cxense analytic
#     var cX = window.cX = window.cX || {}; cX.callQueue = cX.callQueue || [];
#     cX.CCE = cX.CCE || {}; cX.CCE.callQueue = cX.CCE.callQueue || [];
#     cX.callQueue.push(['setSiteId', '1139583540649119209']);
#     cX.CCE.callQueue.push(['sendPageViewEvent']);
#
#     // byteark function
#     byteark = function() {}
#
#     // google publisher tag
#     firstLoad = true // First Request Site
#     innityLoaded = false // Innity Script Loaded
#     firstTimeInnity = false // First time call script Innity
#     googleService = false
#     contentCount = 0
#   </script>
#   <script async="" src="/static/js/prebid3.13.0-3.js">
#   </script>
#   <script async="" src="https://cdn.adnuntius.com/adn.js">
#   </script>
#   <script async="" src="https://tags.adnuntius.com/pb/thairath/thairath.co.th/desktoparticle.js">
#   </script>
#   <meta class="next-head" content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
#   <meta charset="utf-8" class="next-head"/>
#   <title>
#    ข่าวเศรษฐกิจ ราคาหุ้น ทอง น้ำมัน อสังหาฯ การเงิน | ไทยรัฐออนไลน์
#   </title>
#   <script src="https://dev.visualwebsiteoptimizer.com/j.php?a=280223&amp;u=https%3A%2F%2Fwww.thairath.co.th%2Fnews%2Fbusiness&amp;f=1&amp;r=0.2930577666308274" type="text/javascript">
#   </script>
#   <link as="script" href="/_next/static/0VuAbn6iuvNeLCF-rjpAp/pages/news/topic.js" rel="preload"/>
#   <link as="script" href="/_next/static/0VuAbn6iuvNeLCF-rjpAp/pages/_app.js" rel="preload"/>
#   <link as="script" href="/_next/static/runtime/webpack-e52544d3f5a311794eae.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/commons.8f393331aba9c67bd2a9.js" rel="preload"/>
#   <link as="script" href="/_next/static/runtime/main-ebcf269cdbaea505a027.js" rel="preload"/>
#   <style data-emotion-css="18xcx45">
#    .css-18xcx45{max-width:100%;}.css-18xcx45 .container{max-width:1140px;position:relative;}.css-18xcx45 .BgBlackFull{background:#000;width:100%;max-width:unset;}.css-18xcx45 .BgGrayFull{background:#f2f2f2;width:100%;max-width:unset;}.css-18xcx45 .PaddingNone{padding:0;}
#   </style>
#   <style data-emotion-css="6egl3g">
#    .css-6egl3g{position:fixed;top:0;width:100%;-webkit-transition:-webkit-transform 0.5s ease-out;-webkit-transition:-webkit-transform 0.5s ease-out;-webkit-transition:-webkit-transform 0.5s ease-out;transition:-webkit-transform 0.5s ease-out;-o-transition:transform 0.5s ease-out;-webkit-transition:-webkit-transform 0.5s ease-out;-webkit-transition:transform 0.5s ease-out;transition:transform 0.5s ease-out;-webkit-transition:-webkit-transform 0.5s ease-out,-webkit-transform 0.5s ease-out;-webkit-transition:transform 0.5s ease-out,-webkit-transform 0.5s ease-out;transition:transform 0.5s ease-out,-webkit-transform 0.5s ease-out;-webkit-transform:translate3d(0,-0px,550px) !important;-ms-transform:translate3d(0,-0px,550px) !important;transform:translate3d(0,-0px,550px) !important;z-index:999;}
#   </style>
#   <style data-emotion-css="8hnfdp">
#    .css-8hnfdp{position:relative;text-align:center;background-color:#ffffff;display:grid;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 0 15px;height:0px;padding:0 0;}.css-8hnfdp .adBox{display:inline;}.css-8hnfdp #slot-billboard:nth-of-type(1){margin:0 auto;}.css-8hnfdp iframe{min-height:auto !important;}@media (max-width:768px){.css-8hnfdp{margin-bottom:0rem;}}
#   </style>
#   <style data-emotion-css="1ymkx1j">
#    .css-1ymkx1j{position:relative;text-align:center;background-color:#ffffff;display:grid;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 0 15px;-webkit-animation-name:example;animation-name:example;-webkit-animation-duration:0.5s;animation-duration:0.5s;}.css-1ymkx1j .adBox{display:inline;}.css-1ymkx1j #slot-billboard:nth-of-type(1){margin:0 auto;}@-webkit-keyframes example{0%{-webkit-transform:scale(1) translate(-0%,-120%);-ms-transform:scale(1) translate(-0%,-120%);transform:scale(1) translate(-0%,-120%);-moz-transition:transform 0.5s ease-in-out;-o-transition:transform 0.5s ease-in-out;-webkit-transition:transform 0.5s ease-in-out;-webkit-transition:-webkit-transform 0.5s ease-in-out;-webkit-transition:transform 0.5s ease-in-out;transition:transform 0.5s ease-in-out;}100%{-webkit-transform:scale(1) translate(-0%,-1%);-ms-transform:scale(1) translate(-0%,-1%);transform:scale(1) translate(-0%,-1%);-moz-transition:transform 0.5s ease-in-out;-o-transition:transform 0.5s ease-in-out;-webkit-transition:transform 0.5s ease-in-out;-webkit-transition:-webkit-transform 0.5s ease-in-out;-webkit-transition:transform 0.5s ease-in-out;transition:transform 0.5s ease-in-out;}}@keyframes example{0%{-webkit-transform:scale(1) translate(-0%,-120%);-ms-transform:scale(1) translate(-0%,-120%);transform:scale(1) translate(-0%,-120%);-moz-transition:transform 0.5s ease-in-out;-o-transition:transform 0.5s ease-in-out;-webkit-transition:transform 0.5s ease-in-out;-webkit-transition:-webkit-transform 0.5s ease-in-out;-webkit-transition:transform 0.5s ease-in-out;transition:transform 0.5s ease-in-out;}100%{-webkit-transform:scale(1) translate(-0%,-1%);-ms-transform:scale(1) translate(-0%,-1%);transform:scale(1) translate(-0%,-1%);-moz-transition:transform 0.5s ease-in-out;-o-transition:transform 0.5s ease-in-out;-webkit-transition:transform 0.5s ease-in-out;-webkit-transition:-webkit-transform 0.5s ease-in-out;-webkit-transition:transform 0.5s ease-in-out;transition:transform 0.5s ease-in-out;}}.css-1ymkx1j iframe{min-height:auto !important;}@media (max-width:768px){.css-1ymkx1j{margin-bottom:0rem;}}
#   </style>
#   <style data-emotion="css-global">
#   </style>
#   <style data-emotion="css-global">
#   </style>
#   <style data-emotion-css="1vs7tnd">
#    .css-1vs7tnd{background:#fff;height:55px;}.css-1vs7tnd .container{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;}.css-1vs7tnd .collapse:not(.show){display:none;}
#   </style>
#   <style data-emotion-css="1c2xxt9">
#    .css-1c2xxt9{z-index:1;width:110px;margin-right:1rem;display:grid;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.css-1c2xxt9 img{max-width:100%;}.css-1c2xxt9 a{display:grid;}@media (max-width:767px){.css-1c2xxt9{width:100%;margin-right:-15px;display:grid;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}}@media (max-width:991px){.css-1c2xxt9{margin-left:0;}}
#   </style>
#   <style data-emotion-css="a8c9fk">
#    .css-a8c9fk{-webkit-flex:auto;-ms-flex:auto;flex:auto;width:0;}.css-a8c9fk a{color:#000000;-webkit-transition:all 0.3s;transition:all 0.3s;}.css-a8c9fk a:hover{-webkit-transition:all 0.3s;transition:all 0.3s;color:#008841;}@media (max-width:767px){.css-a8c9fk{display:none;}}
#   </style>
#   <style data-emotion-css="1ltqhy5">
#    .css-1ltqhy5{display:-ms-flexbox;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-ms-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;font-weight:100;padding-left:0;margin-bottom:0;list-style:none;margin-top:0;}.css-1ltqhy5 li:nth-of-type(12){display:none;}@media (max-width:800px){.css-1ltqhy5 li:nth-of-type(n + 7){display:none;}}@media (max-width:880px){.css-1ltqhy5 li:nth-of-type(n + 8){display:none;}}@media (max-width:940px){.css-1ltqhy5 li:nth-of-type(n + 10){display:none;}}@media (max-width:1000px){.css-1ltqhy5 li:nth-of-type(n + 11){display:none;}}@media (max-width:1100px){.css-1ltqhy5 li:nth-of-type(n + 12){display:none;}}@media (max-width:1199px){.css-1ltqhy5 li:nth-of-type(n + 13){display:none;}}@media (max-width:991px){.css-1ltqhy5 li{display:none;}.css-1ltqhy5 #isProfile{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}}
#   </style>
#   <style data-emotion-css="1t6yorp">
#    .css-1t6yorp{padding:0 7px;height:55px;line-height:55px;font-family:"cloudregular";font-size:1.2rem;}@media (max-width:768px){.css-1t6yorp{padding:0px;}.css-1t6yorp:not(:nth-of-type(1)){display:none;}}@media (min-width:1181px) and (max-width:1439px){.css-1t6yorp{font-size:1.1rem;}}.css-1t6yorp .submenu{display:none;}.css-1t6yorp:hover .submenu{display:block;top:55px;border:1px solid #E5E5E5;background:#fff;padding-bottom:0.5rem;}.css-1t6yorp:nth-of-type(5){display:none;}
#   </style>
#   <style data-emotion-css="1k0niue">
#    .css-1k0niue{position:absolute;font-size:0.9rem;min-width:10rem;}
#   </style>
#   <style data-emotion-css="y8aj3r">
#    .css-y8aj3r{padding:0;}
#   </style>
#   <style data-emotion-css="1qlshtt">
#    .css-1qlshtt{padding:0rem 1rem;list-style:none;margin-bottom:-10px;font-size:1.2rem;}
#   </style>
#   <style data-emotion-css="1dhr0sg">
#    .css-1dhr0sg{padding:0 5px;position:relative;height:55px;z-index:99;line-height:45px;-webkit-letter-spacing:0.1px;-moz-letter-spacing:0.1px;-ms-letter-spacing:0.1px;letter-spacing:0.1px;line-height:52px;}.css-1dhr0sg a span{font-size:1.2rem;-webkit-letter-spacing:3px;-moz-letter-spacing:3px;-ms-letter-spacing:3px;letter-spacing:3px;}.css-1dhr0sg a span:nth-of-type(1){color:#f4b9c7;font-family:Bodoni-72;}.css-1dhr0sg a span:nth-of-type(2){color:#000000;}.css-1dhr0sg a img{width:115px;margin:3px -10px;}.css-1dhr0sg a svg{width:100px;margin:14px 0px;}@media (max-width:768px){.css-1dhr0sg{padding:0px;}}
#   </style>
#   <style data-emotion-css="14vekce">
#    .css-14vekce{padding:0 5px;position:relative;height:55px;z-index:99;line-height:45px;-webkit-letter-spacing:0.1px;-moz-letter-spacing:0.1px;-ms-letter-spacing:0.1px;letter-spacing:0.1px;text-transform:uppercase;font-size:1.2rem;}.css-14vekce a{color:#8B8B8B;font-family:"cloudregular";}@media (max-width:768px){.css-14vekce{padding:0px;}}
#   </style>
#   <style data-emotion-css="zb46rx">
#    .css-zb46rx{height:55px;line-height:55px;position:relative;}
#   </style>
#   <style data-emotion-css="1rvejc4">
#    .css-1rvejc4{width:10px;height:10px;border-radius:50%;background:#dc3545;display:inline-block;margin-left:8px;top:-3px;position:relative;margin-right:10px;-webkit-animation:Fade 1.5s ease infinite;animation:Fade 1.5s ease infinite;}@-webkit-keyframes Fade{0%{opacity:0.25;}100%{opacity:1;}}@keyframes Fade{0%{opacity:0.25;}100%{opacity:1;}}
#   </style>
#   <style data-emotion-css="15djiy0">
#    .css-15djiy0{height:50px;line-height:3;position:relative;padding:0 0.7rem;padding-left:1.5rem;}@media (max-width:768px){.css-15djiy0{padding:0 1.1rem;}}.css-15djiy0 .nav-menu__hamburger,.css-15djiy0 .nav-menu__hamburger:after,.css-15djiy0 .nav-menu__hamburger:before{background:#00b400;height:2px;width:20px;}.css-15djiy0 .nav-menu__hamburger{margin:-1.5px 0 0 -10px;-webkit-transition:background 0.3s,color 0.2s;-o-transition:background 0.3s,color 0.2s;-webkit-transition:background 0.3s,color 0.2s;transition:background 0.3s,color 0.2s;position:absolute;top:50%;right:0;z-index:32;}.css-15djiy0 .nav-menu__hamburger:after,.css-15djiy0 .nav-menu__hamburger:before{content:"";-webkit-transform-origin:center center;-ms-transform-origin:center center;-webkit-transform-origin:center center;-ms-transform-origin:center center;transform-origin:center center;-webkit-transition:background 0.3s,-webkit-transform 0.3s;-webkit-transition:background 0.3s,-webkit-transform 0.3s;-webkit-transition:background 0.3s,-webkit-transform 0.3s;transition:background 0.3s,-webkit-transform 0.3s;-o-transition:transform 0.3s,background 0.3s;-webkit-transition:-webkit-transform 0.3s,background 0.3s;-webkit-transition:transform 0.3s,background 0.3s;transition:transform 0.3s,background 0.3s;-webkit-transition:-webkit-transform 0.3s,background 0.3s,-webkit-transform 0.3s;-webkit-transition:transform 0.3s,background 0.3s,-webkit-transform 0.3s;transition:transform 0.3s,background 0.3s,-webkit-transform 0.3s;}.css-15djiy0 .nav-menu__hamburger:before{position:absolute;top:-6px;left:0;}.css-15djiy0 .nav-menu__hamburger:after{position:absolute;bottom:-6px;left:0;}.css-15djiy0 nav{cursor:pointer;height:27px;-webkit-transition:color 0.2s;-o-transition:color 0.2s;-webkit-transition:color 0.2s;-webkit-transition:color 0.2s;transition:color 0.2s;width:20px;position:absolute;top:25%;right:0;z-index:32;}.css-15djiy0 nav .nav-menu__hamburger.active{background:rgba(0,0,0,0);}.css-15djiy0 nav .nav-menu__hamburger.active:before{background:#008841;-webkit-transform:translateY(6px) rotate(-45deg);-ms-transform:translateY(6px) rotate(-45deg);-webkit-transform:translateY(6px) rotate(-45deg);-ms-transform:translateY(6px) rotate(-45deg);transform:translateY(6px) rotate(-45deg);}.css-15djiy0 nav .nav-menu__hamburger.active:after{background:#008841;-webkit-transform:translateY(-6px) rotate(45deg);-ms-transform:translateY(-6px) rotate(45deg);-webkit-transform:translateY(-6px) rotate(45deg);-ms-transform:translateY(-6px) rotate(45deg);transform:translateY(-6px) rotate(45deg);}.css-15djiy0 a{color:#00B400;-webkit-transition:all 0.3s;transition:all 0.3s;}.css-15djiy0 svg{fill:#00B400;color:#00B400;-webkit-transition:all 0.3s;transition:all 0.3s;vertical-align:middle;position:relative;}@media (min-width:992px){.css-15djiy0 svg{top:4px;}}.css-15djiy0 svg:hover{color:#008841;-webkit-transition:all 0.3s;transition:all 0.3s;}.css-15djiy0 button{background:none;border:none;cursor:pointer;}@media (max-width:767px){.css-15djiy0{display:none;}}@media (min-width:768px) and (max-width:991px){.css-15djiy0{padding:0 10px;margin-right:0;margin-top:2px;}}
#   </style>
#   <style data-emotion-css="hrbe61">
#    .css-hrbe61{height:50px;line-height:3;position:relative;padding:0 0.7rem;}@media (max-width:768px){.css-hrbe61{padding:0 1.1rem;}}.css-hrbe61 .nav-menu__hamburger,.css-hrbe61 .nav-menu__hamburger:after,.css-hrbe61 .nav-menu__hamburger:before{background:#00b400;height:2px;width:20px;}.css-hrbe61 .nav-menu__hamburger{margin:-1.5px 0 0 -10px;-webkit-transition:background 0.3s,color 0.2s;-o-transition:background 0.3s,color 0.2s;-webkit-transition:background 0.3s,color 0.2s;transition:background 0.3s,color 0.2s;position:absolute;top:50%;right:0;z-index:32;}.css-hrbe61 .nav-menu__hamburger:after,.css-hrbe61 .nav-menu__hamburger:before{content:"";-webkit-transform-origin:center center;-ms-transform-origin:center center;-webkit-transform-origin:center center;-ms-transform-origin:center center;transform-origin:center center;-webkit-transition:background 0.3s,-webkit-transform 0.3s;-webkit-transition:background 0.3s,-webkit-transform 0.3s;-webkit-transition:background 0.3s,-webkit-transform 0.3s;transition:background 0.3s,-webkit-transform 0.3s;-o-transition:transform 0.3s,background 0.3s;-webkit-transition:-webkit-transform 0.3s,background 0.3s;-webkit-transition:transform 0.3s,background 0.3s;transition:transform 0.3s,background 0.3s;-webkit-transition:-webkit-transform 0.3s,background 0.3s,-webkit-transform 0.3s;-webkit-transition:transform 0.3s,background 0.3s,-webkit-transform 0.3s;transition:transform 0.3s,background 0.3s,-webkit-transform 0.3s;}.css-hrbe61 .nav-menu__hamburger:before{position:absolute;top:-6px;left:0;}.css-hrbe61 .nav-menu__hamburger:after{position:absolute;bottom:-6px;left:0;}.css-hrbe61 nav{cursor:pointer;height:27px;-webkit-transition:color 0.2s;-o-transition:color 0.2s;-webkit-transition:color 0.2s;-webkit-transition:color 0.2s;transition:color 0.2s;width:20px;position:absolute;top:25%;right:0;z-index:32;}.css-hrbe61 nav .nav-menu__hamburger.active{background:rgba(0,0,0,0);}.css-hrbe61 nav .nav-menu__hamburger.active:before{background:#008841;-webkit-transform:translateY(6px) rotate(-45deg);-ms-transform:translateY(6px) rotate(-45deg);-webkit-transform:translateY(6px) rotate(-45deg);-ms-transform:translateY(6px) rotate(-45deg);transform:translateY(6px) rotate(-45deg);}.css-hrbe61 nav .nav-menu__hamburger.active:after{background:#008841;-webkit-transform:translateY(-6px) rotate(45deg);-ms-transform:translateY(-6px) rotate(45deg);-webkit-transform:translateY(-6px) rotate(45deg);-ms-transform:translateY(-6px) rotate(45deg);transform:translateY(-6px) rotate(45deg);}
#   </style>
#   <style data-emotion-css="1f0nyxf">
#    .css-1f0nyxf{display:none;color:rgba(0,0,0,0.85);width:100%;padding:2rem 0.5rem;position:relative;height:auto;background:#fffffffd;border:1px solid #e5e5e5;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;overflow-y:auto;}.css-1f0nyxf a{color:rgba(0,0,0,0.85);}.css-1f0nyxf a:hover{color:#00B400;}@media (max-width:768px){.css-1f0nyxf{height:auto;padding-top:0;margin:0;position:absolute;overflow-x:hidden;left:0;}.css-1f0nyxf .container{margin-bottom:2rem;}}.css-1f0nyxf .efr6tej5{grid-gap:10px;}
#   </style>
#   <style data-emotion-css="1kt0mv5">
#    .css-1kt0mv5{display:grid;grid-gap:30px;word-break:break-word;grid-gap:10px;grid-template-columns:480px 1fr;}@media (max-width:1024px) and (min-width:767px){.css-1kt0mv5{grid-gap:20px;}}@media (max-width:990px){.css-1kt0mv5{grid-template-columns:auto;}}@media (max-width:480px){.css-1kt0mv5{grid-template-columns:auto;grid-gap:15px;}}.css-1kt0mv5 .efr6tej12{padding-left:20px;}.css-1kt0mv5 .efr6tej12 .efr6tej12{padding-left:0px;}@media (max-width:767px){.css-1kt0mv5 .efr6tej12{padding:0;}}@media (max-width:991px){.css-1kt0mv5{grid-gap:0;padding:15px 0;}.css-1kt0mv5 .efr6tej5{grid-gap:0;}}@media (min-width:768px) and (max-width:991px){.css-1kt0mv5{grid-template-columns:1fr 1fr;}.css-1kt0mv5 .efr6tej5{grid-template-columns:1fr 1fr;}}@media (min-width:992px) and (max-width:1199px){.css-1kt0mv5{grid-template-columns:410px 1fr;}}
#   </style>
#   <style data-emotion-css="wzdukq">
#    @media (max-width:767px){.css-wzdukq{margin:0;}}@media (max-width:1024px) and (min-width:767px){.css-wzdukq{margin:0;}}.css-wzdukq .animated{-webkit-animation:0.5s ease 0s 1 normal none running animatedItem;animation:0.5s ease 0s 1 normal none running animatedItem;}@-webkit-keyframes animatedItem{0%{-webkit-transform:scale(0.9);-ms-transform:scale(0.9);transform:scale(0.9);opacity:0;}100%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);opacity:1;}}@keyframes animatedItem{0%{-webkit-transform:scale(0.9);-ms-transform:scale(0.9);transform:scale(0.9);opacity:0;}100%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);opacity:1;}}
#   </style>
#   <style data-emotion-css="yhozxu">
#    .css-yhozxu{position:relative;margin-right:15px;display:none;background:#8B8B8B;padding:1rem;margin-top:-1rem;margin-right:-1rem;margin-left:-1rem;}@media (max-width:767px){.css-yhozxu{margin-bottom:5px;}}.css-yhozxu input{width:275px;display:inline-block;color:#626262;border:1px solid #F2F2F2;border-radius:3px 0 0 3px;font-family:"cloudregular";height:25px;padding:10px;vertical-align:top;font-size:1rem;line-height:1.25rem;outline:none;}@media (max-width:767px){.css-yhozxu input{width:85%;}}.css-yhozxu span{vertical-align:top;width:40px;background:#626262;border-radius:0 3px 3px 0;margin:0;border:none;height:25px;}.css-yhozxu span svg{height:14px;}@media (max-width:767px){.css-yhozxu span{width:15%;margin-right:0;}}@media (max-width:767px){.css-yhozxu{display:block;}}.css-yhozxu input{height:27px;}.css-yhozxu span{background:#00B400;height:27px;}
#   </style>
#   <style data-emotion-css="bs35vq">
#    .css-bs35vq{display:inline-grid;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;background:#000;border:1px solid #8b8b8b;cursor:pointer;border-radius:3px;padding:3px 10px;margin:0 0 0 10px;width:13%;-webkit-transition:all 0.2s;transition:all 0.2s;}.css-bs35vq:hover{background:#00b400;}.css-bs35vq svg{width:20px;fill:#fff;}
#   </style>
#   <style data-emotion-css="1gymzrw">
#    .css-1gymzrw{display:grid;grid-gap:30px;word-break:break-word;grid-template-columns:repeat(3,1fr);}@media (max-width:1024px) and (min-width:767px){.css-1gymzrw{grid-gap:20px;}}@media (max-width:990px){.css-1gymzrw{grid-template-columns:auto;}}@media (max-width:480px){.css-1gymzrw{grid-template-columns:auto;grid-gap:15px;}}@media (max-width:767px){.css-1gymzrw .e1u3alx78{display:none;}.css-1gymzrw .e1u3alx78:nth-of-type(1){margin-top:-5px;}.css-1gymzrw .e1u3alx78:nth-of-type(1),.css-1gymzrw .e1u3alx78:nth-of-type(2),.css-1gymzrw .e1u3alx78:nth-of-type(3),.css-1gymzrw .e1u3alx78:nth-of-type(4){display:block;margin-bottom:-10px;}.css-1gymzrw .e1u3alx78:nth-of-type(4){margin-bottom:0px;}}.css-1gymzrw .efr6tej12{margin:0;}
#   </style>
#   <style data-emotion-css="10g2fmx">
#    .css-10g2fmx{font-family:"cloudregular";display:inline-block;vertical-align:top;position:relative;display:none;}@media (max-width:768px){.css-10g2fmx{padding:0;margin-bottom:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;justify-items:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.css-10g2fmx span{grid-column-start:2;}}@media (min-width:768px){.css-10g2fmx .hidden{display:block !important;}}.css-10g2fmx:nth-of-type(1),.css-10g2fmx:nth-of-type(2),.css-10g2fmx:nth-of-type(3),.css-10g2fmx:nth-of-type(4){display:block;}.css-10g2fmx:nth-of-type(4){grid-column:3;margin-top:-230px;}@media (max-width:767px){.css-10g2fmx:nth-of-type(4){grid-column:inherit;margin-top:0;}.css-10g2fmx:nth-of-type(14){grid-row:9;}}@media (min-width:768px) and (max-width:991px){.css-10g2fmx:nth-of-type(4){grid-column:2;margin-top:0;}}@media (min-width:992px) and (max-width:1199px){.css-10g2fmx:nth-of-type(4){margin-top:-230px;}}@media (min-width:768px) and (max-width:768px){.css-10g2fmx{display:none;}.css-10g2fmx:nth-of-type(1),.css-10g2fmx:nth-of-type(2),.css-10g2fmx:nth-of-type(3){display:block !important;}}.css-10g2fmx span a{color:#00b400 !important;font-size:1.5625rem !important;border:none;background:none;outline:none;cursor:pointer;font-family:"cloudsemibold";padding:0;margin:0;margin-bottom:0px;}@media (max-width:767px){.css-10g2fmx span a{margin-bottom:0px;display:block;padding:6px 0;border-bottom:1px solid #e5e5e5;width:100%;text-align:left;margin-top:3px;}}
#   </style>
#   <style data-emotion-css="19mkkdf">
#    .css-19mkkdf{display:inline-block;font-size:1.3rem;font-weight:500;padding:0.2em 0;font-family:"cloudsemibold";}.css-19mkkdf a{display:block;-webkit-transition:all 0.3s;transition:all 0.3s;color:#000;}.css-19mkkdf a:hover{-webkit-transition:all 0.3s;transition:all 0.3s;color:#00b400;}@media (max-width:768px){.css-19mkkdf{font-size:1.05rem;padding:0;width:100%;position:relative;}}
#   </style>
#   <style data-emotion-css="ndsdpn">
#    .css-ndsdpn{color:#000;cursor:pointer;width:10%;text-align:center;position:absolute;right:0;top:10px;}@media (min-width:768px){.css-ndsdpn{display:none;}}
#   </style>
#   <style data-emotion-css="sf7sd3">
#    .css-sf7sd3{margin:0;padding:0;list-style:none;margin-top:10px;display:grid;grid-template-columns:repeat(2,1fr);gap:0px 10px;}@media (max-width:767px){.css-sf7sd3{margin-top:0px;display:block;}}.css-sf7sd3 li{margin-bottom:10px;}.css-sf7sd3 li a{font-family:"cloudregular";color:#626262;font-size:1.125rem;line-height:1.375rem;-webkit-transition:all 0.3s;transition:all 0.3s;}.css-sf7sd3 li a:hover{-webkit-transition:all 0.3s;transition:all 0.3s;color:#00B400;}@media (max-width:767px){.css-sf7sd3 li{background:#e5e5e5;margin:0;padding:10px 15px;}.css-sf7sd3 li:nth-of-type(odd){background:#f2f2f2;}}.css-sf7sd3 .special-menu{margin-bottom:0;margin-top:0;}.css-sf7sd3 .special-menu a{color:#00B400 !important;font-size:1.5625rem !important;border:none;background:none;outline:none;cursor:pointer;font-family:"cloudsemibold";padding:0;margin:0;}@media (max-width:767px){.css-sf7sd3 .special-menu a{margin-bottom:0px;display:block;padding:10px 0;border-bottom:1px solid #e5e5e5;width:100%;text-align:left;margin-top:3px;}}.css-sf7sd3 .menu-head{margin-bottom:15px;}@media (max-width:767px){.css-sf7sd3 .menu-head{margin-bottom:0px;background:none !important;padding:0;margin-top:0px;}}.css-sf7sd3 .menu-head a{color:#00B400 !important;font-size:1.5625rem !important;border:none;background:none;outline:none;cursor:pointer;font-family:"cloudsemibold";padding:0;margin:0;margin-bottom:10px;}@media (max-width:767px){.css-sf7sd3 .menu-head a{margin-bottom:0px;display:block;padding:10px 0;border-bottom:1px solid #e5e5e5;width:100%;text-align:left;margin-top:3px;}}.css-sf7sd3 .menu-head .e1u3alx79{padding:0;}
#   </style>
#   <style data-emotion-css="1jzfo5l">
#    .css-1jzfo5l{display:grid;grid-gap:30px;word-break:break-word;display:none;grid-template-columns:repeat(3,1fr);}@media (max-width:1024px) and (min-width:767px){.css-1jzfo5l{grid-gap:20px;}}@media (max-width:990px){.css-1jzfo5l{grid-template-columns:auto;}}@media (max-width:480px){.css-1jzfo5l{grid-template-columns:auto;grid-gap:15px;}}@media (max-width:767px){.css-1jzfo5l{display:grid;grid-gap:0 !important;}.css-1jzfo5l .special-menu{padding:0;margin-bottom:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;justify-items:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:block;grid-column:span 2;}.css-1jzfo5l .special-menu span{width:100% !important;}.css-1jzfo5l .special-menu a{color:#00B400 !important;font-size:1.5625rem !important;border:none;background:none;outline:none;cursor:pointer;font-family:"cloudsemibold";padding:0;margin:0;margin-bottom:0px;margin-bottom:0px;display:block;padding:6px 0;border-bottom:1px solid #e5e5e5;width:100%;text-align:left;margin-top:3px;}.css-1jzfo5l .e1u3alx78{display:block;grid-column:span 2;}.css-1jzfo5l .e1u3alx78:nth-of-type(1),.css-1jzfo5l .e1u3alx78:nth-of-type(2),.css-1jzfo5l .e1u3alx78:nth-of-type(3),.css-1jzfo5l .e1u3alx78:nth-of-type(4),.css-1jzfo5l .e1u3alx78:nth-of-type(5){display:none;}.css-1jzfo5l .e1u3alx78:nth-of-type(8){display:none;}.css-1jzfo5l .e1u3alx78 a{margin:0;}}.css-1jzfo5l .e1u3alx78:nth-of-type(5),.css-1jzfo5l .e1u3alx78:nth-of-type(8){display:block;}.css-1jzfo5l .e1u3alx78:nth-of-type(7){display:none;}.css-1jzfo5l .e1u3alx78 a{margin:0;}@media (max-width:767px){.css-1jzfo5l .e1u3alx78:nth-of-type(14){grid-row:11;}.css-1jzfo5l .e1u3alx78:nth-of-type(12){grid-row:10;}}.css-1jzfo5l .efr6tej12{margin:0;}
#   </style>
#   <style data-emotion-css="r7lcj0">
#    .css-r7lcj0{display:inline-block;font-size:20px;font-weight:500;padding:0.2em 0;}.css-r7lcj0 a{display:block;}@media (max-width:768px){.css-r7lcj0{font-size:1.05rem;padding:0;width:100%;}}
#   </style>
#   <style data-emotion-css="qdwpap">
#    .css-qdwpap{margin-top:7px;display:none;}@media (max-width:767px){.css-qdwpap{display:block;border-bottom:1px solid #e5e5e5;padding-bottom:10px;margin-top:15px;grid-row:4;grid-column:span 2;}}
#   </style>
#   <style data-emotion-css="jzm49q">
#    .css-jzm49q{display:none;}.css-jzm49q a{color:#00B400 !important;font-size:1.5625rem;border:none;background:none;outline:none;cursor:pointer;font-family:"cloudsemibold";padding:0;margin:0;margin-bottom:0px;}@media (max-width:767px){.css-jzm49q{display:block;border-bottom:1px solid #e5e5e5;padding-bottom:5px;margin-top:9px;grid-row:5;grid-column:span 2;}}
#   </style>
#   <style data-emotion-css="xxydhw">
#    .css-xxydhw{border-left:1px solid #E5E5E5;}@media (max-width:767px){.css-xxydhw{margin:0;}}@media (max-width:1024px) and (min-width:767px){.css-xxydhw{margin:0;}}.css-xxydhw .animated{-webkit-animation:0.5s ease 0s 1 normal none running animatedItem;animation:0.5s ease 0s 1 normal none running animatedItem;}@-webkit-keyframes animatedItem{0%{-webkit-transform:scale(0.9);-ms-transform:scale(0.9);transform:scale(0.9);opacity:0;}100%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);opacity:1;}}@keyframes animatedItem{0%{-webkit-transform:scale(0.9);-ms-transform:scale(0.9);transform:scale(0.9);opacity:0;}100%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);opacity:1;}}@media (max-width:767px){.css-xxydhw{border:none;}}
#   </style>
#   <style data-emotion-css="dhclvh">
#    .css-dhclvh{display:grid;grid-gap:30px;word-break:break-word;grid-template-columns:315px 1fr;}@media (max-width:1024px) and (min-width:767px){.css-dhclvh{grid-gap:20px;}}@media (max-width:990px){.css-dhclvh{grid-template-columns:auto;}}@media (max-width:480px){.css-dhclvh{grid-template-columns:auto;grid-gap:15px;}}@media (max-width:767px){.css-dhclvh{grid-template-columns:repeat(2 ,1fr);}.css-dhclvh .efr6tej12{grid-column:span 2;display:grid;grid-template-columns:repeat(2 ,1fr);-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.css
"https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8skuzbXNyx8ec0WVJqDoP03pP0IK.jpg","canonical":"https://www.thairath.co.th/news/business/stocks-gold/1889291"},{"id":1889144,"type":"content","title":"แบงก์ชาติ ประเมินเศรษฐกิจไทยผ่านจุดต่ำสุดในไตรมาส 2 หลังโควิด-19 ระบาด","section":"ข่าว","sectionEn":"news","topic":"เศรษฐกิจ","topicEn":"business","topicPath":"/news/business","fullPath":"/news/business/1889144","abstract":"ธนาคารแห่งประเทศไทย ประเมินเศรษฐกิจไทยผ่านจุดต่ำสุดในไตรมาส 2 ของปี 63 หลังมีการแพร่ระบาดของโควิด-19 ...
#   </script>
#   <script async="" id="__NEXT_PAGE__/news/topic" src="/_next/static/0VuAbn6iuvNeLCF-rjpAp/pages/news/topic.js">
#   </script>
#   <script async="" id="__NEXT_PAGE__/_app" src="/_next/static/0VuAbn6iuvNeLCF-rjpAp/pages/_app.js">
#   </script>
#   <script async="" src="/_next/static/runtime/webpack-e52544d3f5a311794eae.js">
#   </script>
#   <script async="" src="/_next/static/chunks/commons.8f393331aba9c67bd2a9.js">
#   </script>
#   <script async="" src="/_next/static/runtime/main-ebcf269cdbaea505a027.js">
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## Select section `ข่าวอื่นๆ` in order to navigate through news

# %%
sel = soup.find('h3', text='ข่าวอื่นๆ').find_next('div').find_all('a')

sel
# Out:
# [<a href="/news/business/1886753"><img alt="ชงตั้งศูนย์ฟื้นฟูเศรษฐกิจ “บิ๊กตู่” รับข้อเสนอบูรณาการทุกส่วนกู้ประเทศ" class="css-ckexjm erf07a90" src="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxdO3Ya.jpg"/></a>,
#  <a href="/news/business/1886753">ชงตั้งศูนย์ฟื้นฟูเศรษฐกิจ “บิ๊กตู่” รับข้อเสนอบูรณาการทุกส่วนกู้ประเทศ</a>,
#  <a href="/news/business/1886473"><img alt='"เราเที่ยวด้วยกัน" เปิดให้เช็ก ร้านอาหาร โรงแรม ที่เข้าร่วมโครงการแล้ว' class="css-ckexjm erf07a90" src="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slALXDzEWmf6vnsxUNPVZD6S3tm.jpg"/></a>,
#  <a href="/news/business/1886473">"เราเที่ยวด้วยกัน" เปิดให้เช็ก ร้านอาหาร โรงแรม ที่เข้าร่วมโครงการแล้ว</a>,
#  <a href="/news/business/1886795"><img alt='ผุด "ศูนย์ฟื้นฟู ศก." กู้พิษโควิดฯ ยึดโมเดล ศบค.แก้ปัญหาม้วนเดียวจบ' class="css-ckexjm erf07a90" src="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMwmApR4nJ4vO3CYsY59mN5ww.jpg"/></a>,
#  <a href="/news/business/1886795">ผุด "ศูนย์ฟื้นฟู ศก." กู้พิษโควิดฯ ยึดโมเดล ศบค.แก้ปัญหาม้วนเดียวจบ</a>,
#  <a href="/news/business/1886784"><img alt="ก.คมนาคม ถก ทูตญี่ปุ่น จับคู่เดินทางระหว่างประเทศ คาดสรุปได้สัปดาห์หน้า" class="css-ckexjm erf07a90" src="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMwkHPIFdS4TlfhSLaPKz5nxQ.jpg"/></a>,
#  <a href="/news/business/1886784">ก.คมนาคม ถก ทูตญี่ปุ่น จับคู่เดินทางระหว่างประเทศ คาดสรุปได้สัปดาห์หน้า</a>,
#  <a href="/news/business/1886508"><img alt="กองสลากฯ ยอมรับหวยงวด 1 ส.ค.63 หลุดขายก่อนกำหนด ยันขึ้นเงินได้ปกติ" class="css-ckexjm erf07a90" src="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAL9RSfCMTqHVG298g9nNCavfC.jpg"/></a>,
#  <a href="/news/business/1886508">กองสลากฯ ยอมรับหวยงวด 1 ส.ค.63 หลุดขายก่อนกำหนด ยันขึ้นเงินได้ปกติ</a>,
#  <a href="/news/business/1886495"><img alt='อย่าลืมแวะเติม ปตท. บางจาก ประกาศปรับขึ้น "ราคาน้ำมัน" ทุกชนิด' class="css-ckexjm erf07a90" src="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slALV2mFp5rQJ2RYfa4EX9uX358.jpg"/></a>,
#  <a href="/news/business/1886495">อย่าลืมแวะเติม ปตท. บางจาก ประกาศปรับขึ้น "ราคาน้ำมัน" ทุกชนิด</a>,
#  <a href="/news/business/1886423"><img alt="เราเที่ยวด้วยกัน ตอบ 8 คำถามคาใจ เตรียมพร้อมก่อนลงทะเบียนชิงสิทธิ์เที่ยว" class="css-ckexjm erf07a90" src="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slALWqGugJUJZPy3DXjgh084yP5.jpg"/></a>,
#  <a href="/news/business/1886423">เราเที่ยวด้วยกัน ตอบ 8 คำถามคาใจ เตรียมพร้อมก่อนลงทะเบียนชิงสิทธิ์เที่ยว</a>,
#  <a href="/news/business/1886413"><img alt="คลัง สมทบให้ครบ 5,000 ช่วยประกันสังคมจ่ายผู้ประกันตนทำงานไม่ถึง 26 วัน" class="css-ckexjm erf07a90" src="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slALW1vHZtVzn74r46LPuEAh20N.jpg"/></a>,
#  <a href="/news/business/1886413">คลัง สมทบให้ครบ 5,000 ช่วยประกันสังคมจ่ายผู้ประกันตนทำงานไม่ถึง 26 วัน</a>,
#  <a href="/news/business/stocks-gold/1886315"><img alt="หุ้นไทยวันนี้ ปิดตลาดเช้า ปรับลด 8.70 ดัชนีอยู่ที่ 1,322 จุด" class="css-ckexjm erf07a90" src="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAOy9ONpgRF4vFU0253aPXJ1ss.jpg"/></a>,
#  <a href="/news/business/stocks-gold/1886315">หุ้นไทยวันนี้ ปิดตลาดเช้า ปรับลด 8.70 ดัชนีอยู่ที่ 1,322 จุด</a>,
#  <a href="/news/business/1885045"><img alt="ตรวจสอบสิทธิ์ 'เยียวยาเกษตรกร' เช็กด่วน ธ.ก.ส. โอนเงินให้กลุ่มแจ้งบัญชีใหม่แล้ว" class="css-ckexjm erf07a90" src="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8sk3m31RhIZ8HrOhkpph40Tsizju.jpg"/></a>,
#  <a href="/news/business/1885045">ตรวจสอบสิทธิ์ 'เยียวยาเกษตรกร' เช็กด่วน ธ.ก.ส. โอนเงินให้กลุ่มแจ้งบัญชีใหม่แล้ว</a>,
#  <a href="/news/business/1886135"><img alt="วิธีลงทะเบียน www.เราเที่ยวด้วยกัน.com ชิงสิทธิ์แจกเงินเที่ยว จำนวนจำกัด (คลิป)" class="css-ckexjm erf07a90" src="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAN9oa3RGrJwSBJBJzmgXhs9z9.jpg"/></a>,
#  <a href="/news/business/1886135">วิธีลงทะเบียน www.เราเที่ยวด้วยกัน.com ชิงสิทธิ์แจกเงินเที่ยว จำนวนจำกัด (คลิป)</a>,
#  <a href="/news/business/finance-banking/1886164"><img alt="ตลาดตราสารหนี้ผวา หลังเจอโควิด-19 ทำ 6 เดือนแรกเอกชนออกขายหุ้นกู้ลดลง" class="css-ckexjm erf07a90" src="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAOAVKsSI0e7ls4JVjzV4z8vdU.jpg"/></a>,
#  <a href="/news/business/finance-banking/1886164">ตลาดตราสารหนี้ผวา หลังเจอโควิด-19 ทำ 6 เดือนแรกเอกชนออกขายหุ้นกู้ลดลง</a>]

# %%
len(sel)
# Out:
# 24

# %%
sel[0]
# Out:
# <a href="/news/business/1886753"><img alt="ชงตั้งศูนย์ฟื้นฟูเศรษฐกิจ “บิ๊กตู่” รับข้อเสนอบูรณาการทุกส่วนกู้ประเทศ" class="css-ckexjm erf07a90" src="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxdO3Ya.jpg"/></a>

# %%
sel[0]['href']
# Out:
# '/news/business/1886753'

# %%
ss = sel[0].find('img')['src']
ss
# Out:
# 'https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxdO3Ya.jpg'

# %%
sel[1]
# Out:
# <a href="/news/business/1886753">ชงตั้งศูนย์ฟื้นฟูเศรษฐกิจ “บิ๊กตู่” รับข้อเสนอบูรณาการทุกส่วนกู้ประเทศ</a>

# %% [markdown]
# It is found that the a-tags next to the `ข่าวอื่นๆ` section contain a pair of links for each news. In specific, it has clickable image and headline with link. Therefore, there are 2 times a-tags than required. In this case, only the first one from the pair is selected.

# %%
# collect news links and images. Prepare to navigate through these links.
link_l = []
img_l = []
news = {'title': [], 'pub_date': [], 'desc': [], 'tag': [], 'cover_img': [], 'url': [], 'cat': []}
for i, s in enumerate(sel):
    if i%2 == 1:
        continue
    news['url'].append('https://www.thairath.co.th'+s['href']) 
    news['cover_img'].append(s.find('img')['src'])
    news['title'].append(s.find('img')['alt'])

# %%
news['url']
# Out:
# ['https://www.thairath.co.th/news/business/1886753',
#  'https://www.thairath.co.th/news/business/1886473',
#  'https://www.thairath.co.th/news/business/1886795',
#  'https://www.thairath.co.th/news/business/1886784',
#  'https://www.thairath.co.th/news/business/1886508',
#  'https://www.thairath.co.th/news/business/1886495',
#  'https://www.thairath.co.th/news/business/1886423',
#  'https://www.thairath.co.th/news/business/1886413',
#  'https://www.thairath.co.th/news/business/stocks-gold/1886315',
#  'https://www.thairath.co.th/news/business/1885045',
#  'https://www.thairath.co.th/news/business/1886135',
#  'https://www.thairath.co.th/news/business/finance-banking/1886164']

# %%
news['url'][-1].split('/')
# Out:
# ['https:',
#  '',
#  'www.thairath.co.th',
#  'news',
#  'business',
#  'finance-banking',
#  '1886164']

# %%
news['url'][-1].split('/')[4]
# Out:
# 'business'

# %%
news['cover_img']
# Out:
# ['https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxdO3Ya.jpg',
#  'https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slALXDzEWmf6vnsxUNPVZD6S3tm.jpg',
#  'https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMwmApR4nJ4vO3CYsY59mN5ww.jpg',
#  'https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMwkHPIFdS4TlfhSLaPKz5nxQ.jpg',
#  'https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAL9RSfCMTqHVG298g9nNCavfC.jpg',
#  'https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slALV2mFp5rQJ2RYfa4EX9uX358.jpg',
#  'https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slALWqGugJUJZPy3DXjgh084yP5.jpg',
#  'https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slALW1vHZtVzn74r46LPuEAh20N.jpg',
#  'https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAOy9ONpgRF4vFU0253aPXJ1ss.jpg',
#  'https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8sk3m31RhIZ8HrOhkpph40Tsizju.jpg',
#  'https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAN9oa3RGrJwSBJBJzmgXhs9z9.jpg',
#  'https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAOAVKsSI0e7ls4JVjzV4z8vdU.jpg']

# %%
news['title']
# Out:
# ['ชงตั้งศูนย์ฟื้นฟูเศรษฐกิจ “บิ๊กตู่” รับข้อเสนอบูรณาการทุกส่วนกู้ประเทศ',
#  '"เราเที่ยวด้วยกัน" เปิดให้เช็ก ร้านอาหาร โรงแรม ที่เข้าร่วมโครงการแล้ว',
#  'ผุด "ศูนย์ฟื้นฟู ศก." กู้พิษโควิดฯ ยึดโมเดล ศบค.แก้ปัญหาม้วนเดียวจบ',
#  'ก.คมนาคม ถก ทูตญี่ปุ่น จับคู่เดินทางระหว่างประเทศ คาดสรุปได้สัปดาห์หน้า',
#  'กองสลากฯ ยอมรับหวยงวด 1 ส.ค.63 หลุดขายก่อนกำหนด ยันขึ้นเงินได้ปกติ',
#  'อย่าลืมแวะเติม ปตท. บางจาก ประกาศปรับขึ้น "ราคาน้ำมัน" ทุกชนิด',
#  'เราเที่ยวด้วยกัน ตอบ 8 คำถามคาใจ เตรียมพร้อมก่อนลงทะเบียนชิงสิทธิ์เที่ยว',
#  'คลัง สมทบให้ครบ 5,000 ช่วยประกันสังคมจ่ายผู้ประกันตนทำงานไม่ถึง 26 วัน',
#  'หุ้นไทยวันนี้ ปิดตลาดเช้า ปรับลด 8.70 ดัชนีอยู่ที่ 1,322 จุด',
#  "ตรวจสอบสิทธิ์ 'เยียวยาเกษตรกร' เช็กด่วน ธ.ก.ส. โอนเงินให้กลุ่มแจ้งบัญชีใหม่แล้ว",
#  'วิธีลงทะเบียน www.เราเที่ยวด้วยกัน.com ชิงสิทธิ์แจกเงินเที่ยว จำนวนจำกัด (คลิป)',
#  'ตลาดตราสารหนี้ผวา หลังเจอโควิด-19 ทำ 6 เดือนแรกเอกชนออกขายหุ้นกู้ลดลง']

# %%
driver = webdriver.Chrome('C:\Program Files\Google\chromedriver.exe')
driver.get(news['url'][0])
soup = BeautifulSoup(driver.page_source, 'lxml')

driver.close()
print(soup.prettify())
# Out:
# <html lang="th">
#  <head>
#   <meta charset="utf-8"/>
#   <link data-react-helmet="true" href="https://www.thairath.co.th/news/business/1886753" rel="canonical"/>
#   <link data-react-helmet="true" href="https://www.thairath.co.th/media/dFQROr7oWzulq5FZUECroFFdX5kBhiSY2Xdz8F80X5zqmHQNLTOzWnbJ2caLHjezk7C.jpg" rel="image_src"/>
#   <meta content="ชงตั้งศูนย์ฟื้นฟูเศรษฐกิจ “บิ๊กตู่” รับข้อเสนอบูรณาการทุกส่วนกู้ประเทศ" data-react-helmet="true" property="og:title"/>
#   <meta content="https://www.thairath.co.th/news/business/1886753" data-react-helmet="true" property="og:url"/>
#   <meta content="นายกฯเปิดเวทีหารือทีมที่ปรึกษาเศรษฐกิจชุดใหญ่ รับข้อเสนอตั้งศูนย์ฟื้นฟูเศรษฐกิจ รูปแบบเดียวกับ ศบค.พร้อมชงให้นายกฯนั่งเป็นประธาน เพื่อให้บูรณาการระหว่างหน่วยงาน" data-react-helmet="true" property="og:description"/>
#   <meta content="https://www.thairath.co.th/media/dFQROr7oWzulq5FZUECroFFdX5kBhiSY2Xdz8F80X5zqmHQNLTOzWnbJ2caLHjezk7C.jpg" data-react-helmet="true" property="og:image"/>
#   <meta content="2020-07-11T07:01:00+07:00" data-react-helmet="true" property="og:article:published_time"/>
#   <meta content="2020-07-11T07:01:00+07:00" data-react-helmet="true" property="article:published_time"/>
#   <meta content="2020-07-11T07:01:00+07:00" data-react-helmet="true" property="article:modified_time"/>
#   <meta content="ฟื้นฟูเศรษฐกิจ,ทีมเศรษฐกิจชุดใหญ่,ตลาดหุ้น SME,ประยุทธ์ จันทร์โอชา,กลินท์ สารสิน,SME,ข่าววันนี้" data-react-helmet="true" name="keywords"/>
#   <meta content="นายกฯเปิดเวทีหารือทีมที่ปรึกษาเศรษฐกิจชุดใหญ่ รับข้อเสนอตั้งศูนย์ฟื้นฟูเศรษฐกิจ รูปแบบเดียวกับ ศบค.พร้อมชงให้นายกฯนั่งเป็นประธาน เพื่อให้บูรณาการระหว่างหน่วยงาน" data-react-helmet="true" name="description"/>
#   <meta content="https://www.thairath.co.th/media/dFQROr7oWzulq5FZUECroFFdX5kBhiSY2Xdz8F80X5zqmHQNLTOzWnbJ2caLHjezk7C.jpg" data-react-helmet="true" name="twitter:image"/>
#   <meta content="https://www.thairath.co.th/news/business/1886753" data-react-helmet="true" name="twitter:site"/>
#   <meta content="content-1886753" data-react-helmet="true" name="cXenseParse:articleid"/>
#   <meta content="article" data-react-helmet="true" name="cXenseParse:pageclass"/>
#   <meta content="ชงตั้งศูนย์ฟื้นฟูเศรษฐกิจ “บิ๊กตู่” รับข้อเสนอบูรณาการทุกส่วนกู้ประเทศ" data-react-helmet="true" name="cXenseParse:title"/>
#   <meta content="นายกฯเปิดเวทีหารือทีมที่ปรึกษาเศรษฐกิจชุดใหญ่ รับข้อเสนอตั้งศูนย์ฟื้นฟูเศรษฐกิจ รูปแบบเดียวกับ ศบค.พร้อมชงให้นายกฯนั่งเป็นประธาน เพื่อให้บูรณาการระหว่างหน่วยงาน" data-react-helmet="true" name="cXenseParse:description"/>
#   <meta content="print" data-react-helmet="true" name="cXenseParse:trt-contentsource"/>
#   <meta content="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxaTNKT.jpg" data-react-helmet="true" name="cXenseParse:trt-imagesmall"/>
#   <meta content="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxYTsqk.jpg" data-react-helmet="true" name="cXenseParse:trt-image"/>
#   <meta content="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxdO3Ya.jpg" data-react-helmet="true" name="cXenseParse:trt-imagelarge"/>
#   <meta content="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxaTNKT.jpg" data-react-helmet="true" name="tr:imagesmall"/>
#   <meta content="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxYTsqk.jpg" data-react-helmet="true" name="tr:image"/>
#   <meta content="https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxdO3Ya.jpg" data-react-helmet="true" name="tr:imagelarge"/>
#   <meta content="content" data-react-helmet="true" name="cXenseParse:trt-contenttype"/>
#   <meta content="article" data-react-helmet="true" name="cXenseParse:trt-mediatype"/>
#   <meta content="news" data-react-helmet="true" name="cXenseParse:trt-contentsection"/>
#   <meta content="business" data-react-helmet="true" name="cXenseParse:trt-contenttopic"/>
#   <meta content="ฟื้นฟูเศรษฐกิจ" data-react-helmet="true" name="cXenseParse:trt-keywords"/>
#   <meta content="ทีมเศรษฐกิจชุดใหญ่" data-react-helmet="true" name="cXenseParse:trt-keywords"/>
#   <meta content="ตลาดหุ้น SME" data-react-helmet="true" name="cXenseParse:trt-keywords"/>
#   <meta content="ประยุทธ์ จันทร์โอชา" data-react-helmet="true" name="cXenseParse:trt-keywords"/>
#   <meta content="กลินท์ สารสิน" data-react-helmet="true" name="cXenseParse:trt-keywords"/>
#   <meta content="SME" data-react-helmet="true" name="cXenseParse:trt-keywords"/>
#   <meta content="ข่าววันนี้" data-react-helmet="true" name="cXenseParse:trt-keywords"/>
#   <meta content="news" data-react-helmet="true" name="cXenseParse:category"/>
#   <meta content="business" data-react-helmet="true" name="cXenseParse:category"/>
#   <meta content="news" data-react-helmet="true" name="cXenseParse:taxonomy"/>
#   <meta content="news/business" data-react-helmet="true" name="cXenseParse:taxonomy"/>
#   <meta content="https://www.thairath.co.th" name="webiste-url"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="Thairath" name="apple-mobile-web-app-title"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="#424242" name="msapplication-TileColor"/>
#   <meta content="/static/img/favicon/ms-icon-144x144.png" name="msapplication-TileImage"/>
#   <meta content="#424242" name="theme-color"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="630" property="og:image:height"/>
#   <meta content="www.thairath.co.th" property="og:site_name"/>
#   <meta content="639717687" property="fb:admins"/>
#   <meta content="546617158831626" property="fb:app_id"/>
#   <meta content="article" property="og:type"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <link href="/static/img/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/static/img/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="/static/img/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/static/img/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/static/img/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/static/img/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/static/img/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="/static/img/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/static/img/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/static/img/favicon/favicon-32x32.png" rel="icon" type="image/x-icon"/>
#   <link href="/static/img/favicon/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="/static/img/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/static/img/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="/static/img/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/static/json/manifest.json" rel="manifest"/>
#   <link href="//lvs2.truehits.in.th" rel="preconnect"/>
#   <link href="//player.h-cdn.com" rel="preconnect"/>
#   <link href="//perr.h-cdn.com" rel="preconnect"/>
#   <link href="//facebook.com" rel="preconnect"/>
#   <link href="//staticxx.facebook.com" rel="preconnect"/>
#   <link href="//i.liadm.com" rel="preconnect"/>
#   <link href="//loadm.exelator.com" rel="preconnect"/>
#   <link href="//pxl.connexity.net" rel="preconnect"/>
#   <link href="//d.agkn.com" rel="preconnect"/>
#   <link href="//aa.agkn.com" rel="preconnect"/>
#   <link href="//idsync.rlcdn.com" rel="preconnect"/>
#   <link href="//pippio.com" rel="preconnect"/>
#   <link href="//sync.crwdcntrl.net" rel="preconnect"/>
#   <link href="//ml314.com" rel="preconnect"/>
#   <link href="//load77.exelator.com" rel="preconnect"/>
#   <link href="//tags.rd.linksynergy.com" rel="preconnect"/>
#   <link href="//fonts.googleapis.com" rel="preconnect"/>
#   <link href="//fonts.gstatic.com" rel="preconnect"/>
#   <link href="//google-analytics.com" rel="preconnect"/>
#   <link href="//p1cluster.cxense.com" rel="preconnect"/>
#   <link href="//comcluster.cxense.com" rel="preconnect"/>
#   <link href="//api.cxense.com" rel="preconnect"/>
#   <link href="//tpc.googlesyndication.com" rel="preconnect"/>
#   <link href="https://scomcluster.cxense.com" rel="preconnect"/>
#   <link href="https://scdn.cxense.com" rel="preconnect"/>
#   <link href="https://www.googletagservices.com" rel="preconnect"/>
#   <link href="https://connect.facebook.net" rel="preconnect"/>
#   <link href="https://id.cxense.com" rel="preconnect"/>
#   <link href="https://cdn.cxense.com" rel="preconnect"/>
#   <link href="http://api.popin.cc/searchbox/thairath_th.js" rel="preconnect"/>
#   <link href="https://ad.doubleclick.net" rel="preconnect"/>
#   <link href="https://sp1cluster.cxense.com" rel="preconnect"/>
#   <link as="font" href="/static/font/Cloud-LightBold/cloud-regular-webfont.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" href="/static/font/Cloud-LightBold/cloud-semibold-webfont.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" href="/static/font/MN_by_DB/MN%20Paethai%20v3.2.1.ttf" rel="preload" type="font/ttf"/>
#   <link as="font" href="/static/font/MN_by_DB/MN%20Paethai%20Med%20v3.2.1.ttf" rel="preload" type="font/ttf"/>
#   <link href="https://tags.adnuntius.com/pb/thairath/thairath.co.th/desktop.js" rel="preload"/>
#   <link href="https://tags.adnuntius.com/pb/thairath/thairath.co.th/mobile.js" rel="preload"/>
#   <style>
#   </style>
#   <style>
#    .container{width:100%;padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}@media (min-width:576px){.container{max-width:540px}}@media (min-width:768px){.container{max-width:720px}}@media (min-width:992px){.container{max-width:960px}}@media (min-width:1200px){.container{max-width:1140px}}.container-fluid{width:100%;padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}.row{display:flex;flex-wrap:wrap;margin-right:-15px;margin-left:-15px}.no-gutters{margin-right:0;margin-left:0}.no-gutters>.col,.no-gutters>[class*=col-]{padding-right:0;padding-left:0}.col,.col-1,.col-2,.col-3,.col-4,.col-5,.col-6,.col-7,.col-8,.col-9,.col-10,.col-11,.col-12,.col-auto,.col-lg,.col-lg-1,.col-lg-2,.col-lg-3,.col-lg-4,.col-lg-5,.col-lg-6,.col-lg-7,.col-lg-8,.col-lg-9,.col-lg-10,.col-lg-11,.col-lg-12,.col-lg-auto,.col-md,.col-md-1,.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9,.col-md-10,.col-md-11,.col-md-12,.col-md-auto,.col-sm,.col-sm-1,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9,.col-sm-10,.col-sm-11,.col-sm-12,.col-sm-auto,.col-xl,.col-xl-1,.col-xl-2,.col-xl-3,.col-xl-4,.col-xl-5,.col-xl-6,.col-xl-7,.col-xl-8,.col-xl-9,.col-xl-10,.col-xl-11,.col-xl-12,.col-xl-auto{position:relative;width:100%;padding-right:15px;padding-left:15px}.col{flex-basis:0;flex-grow:1;max-width:100%}.col-auto{flex:0 0 auto;width:auto;max-width:100%}.col-1{flex:0 0 8.33333%;max-width:8.33333%}.col-2{flex:0 0 16.66667%;max-width:16.66667%}.col-3{flex:0 0 25%;max-width:25%}.col-4{flex:0 0 33.33333%;max-width:33.33333%}.col-5{flex:0 0 41.66667%;max-width:41.66667%}.col-6{flex:0 0 50%;max-width:50%}.col-7{flex:0 0 58.33333%;max-width:58.33333%}.col-8{flex:0 0 66.66667%;max-width:66.66667%}.col-9{flex:0 0 75%;max-width:75%}.col-10{flex:0 0 83.33333%;max-width:83.33333%}.col-11{flex:0 0 91.66667%;max-width:91.66667%}.col-12{flex:0 0 100%;max-width:100%}.order-first{order:-1}.order-last{order:13}.order-0{order:0}.order-1{order:1}.order-2{order:2}.order-3{order:3}.order-4{order:4}.order-5{order:5}.order-6{order:6}.order-7{order:7}.order-8{order:8}.order-9{order:9}.order-10{order:10}.order-11{order:11}.order-12{order:12}.offset-1{margin-left:8.33333%}.offset-2{margin-left:16.66667%}.offset-3{margin-left:25%}.offset-4{margin-left:33.33333%}.offset-5{margin-left:41.66667%}.offset-6{margin-left:50%}.offset-7{margin-left:58.33333%}.offset-8{margin-left:66.66667%}.offset-9{margin-left:75%}.offset-10{margin-left:83.33333%}.offset-11{margin-left:91.66667%}@media (min-width:576px){.col-sm{flex-basis:0;flex-grow:1;max-width:100%}.col-sm-auto{flex:0 0 auto;width:auto;max-width:100%}.col-sm-1{flex:0 0 8.33333%;max-width:8.33333%}.col-sm-2{flex:0 0 16.66667%;max-width:16.66667%}.col-sm-3{flex:0 0 25%;max-width:25%}.col-sm-4{flex:0 0 33.33333%;max-width:33.33333%}.col-sm-5{flex:0 0 41.66667%;max-width:41.66667%}.col-sm-6{flex:0 0 50%;max-width:50%}.col-sm-7{flex:0 0 58.33333%;max-width:58.33333%}.col-sm-8{flex:0 0 66.66667%;max-width:66.66667%}.col-sm-9{flex:0 0 75%;max-width:75%}.col-sm-10{flex:0 0 83.33333%;max-width:83.33333%}.col-sm-11{flex:0 0 91.66667%;max-width:91.66667%}.col-sm-12{flex:0 0 100%;max-width:100%}.order-sm-first{order:-1}.order-sm-last{order:13}.order-sm-0{order:0}.order-sm-1{order:1}.order-sm-2{order:2}.order-sm-3{order:3}.order-sm-4{order:4}.order-sm-5{order:5}.order-sm-6{order:6}.order-sm-7{order:7}.order-sm-8{order:8}.order-sm-9{order:9}.order-sm-10{order:10}.order-sm-11{order:11}.order-sm-12{order:12}.offset-sm-0{margin-left:0}.offset-sm-1{margin-left:8.33333%}.offset-sm-2{margin-left:16.66667%}.offset-sm-3{margin-left:25%}.offset-sm-4{margin-left:33.33333%}.offset-sm-5{margin-left:41.66667%}.offset-sm-6{margin-left:50%}.offset-sm-7{margin-left:58.33333%}.offset-sm-8{margin-left:66.66667%}.offset-sm-9{margin-left:75%}.offset-sm-10{margin-left:83.33333%}.offset-sm-11{margin-left:91.66667%}}@media (min-width:768px){.col-md{flex-basis:0;flex-grow:1;max-width:100%} ...
#   </style>
#   <style>
#    #nprogress{pointer-events:none}#nprogress .bar{background:#29d;position:fixed;z-index:1031;top:0;left:0;width:100%;height:2px}#nprogress .peg{display:block;position:absolute;right:0;width:100px;height:100%;box-shadow:0 0 10px #29d,0 0 5px #29d;opacity:1;transform:rotate(3deg) translateY(-4px)}#nprogress .spinner{display:block;position:fixed;z-index:1031;top:15px;right:15px}#nprogress .spinner-icon{width:18px;height:18px;box-sizing:border-box;border-color:#29d transparent transparent #29d;border-style:solid;border-width:2px;border-radius:50%;-webkit-animation:nprogress-spinner .4s linear infinite;animation:nprogress-spinner .4s linear infinite}.nprogress-custom-parent{overflow:hidden;position:relative}.nprogress-custom-parent #nprogress .bar,.nprogress-custom-parent #nprogress .spinner{position:absolute}@-webkit-keyframes nprogress-spinner{0%{-webkit-transform:rotate(0deg)}to{-webkit-transform:rotate(1turn)}}@keyframes nprogress-spinner{0%{transform:rotate(0deg)}to{transform:rotate(1turn)}}
#   </style>
#   <style>
#    *{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;-webkit-overflow-scrolling:touch}*,:after,:before{box-sizing:border-box}body{padding:170px 0 0;margin:0;letter-spacing:.2px;color:#292929}@font-face{font-display:swap;font-family:DB ComYard X;src:url(/static/font/DBComYardX/subset-DBComYardX-Bold.eot);src:url(/static/font/DBComYardX/subset-DBComYardX-Bold.eot?#iefix) format("embedded-opentype"),url(/static/font/DBComYardX/subset-DBComYardX-Bold.woff2) format("woff2"),url(/static/font/DBComYardX/subset-DBComYardX-Bold.woff) format("woff"),url(/static/font/DBComYardX/subset-DBComYardX-Bold.ttf) format("truetype"),url(/static/font/DBComYardX/subset-DBComYardX-Bold.svg#DBComYardX-Bold) format("svg");font-weight:700;font-style:normal}h1,h2,h3,h4,h5,h6{margin-top:0;margin-bottom:.5rem;font-family:inherit;line-height:1.2;color:inherit;font-weight:400;-webkit-font-smoothing:auto}h1{font-size:2rem}h4{color:#333;font-weight:300;line-height:1.5}a{background-color:transparent;color:#01b400}a,a:hover{text-decoration:none}a:hover{color:#999}.text-center{text-align:center}.hidden{display:none!important}dl,ol{margin-top:0;margin-bottom:1rem}ol.alignleft{text-align:left;font-size:.85rem}ol.alignleft li{margin-bottom:.5rem}.true-hits{position:absolute;margin:0 1rem;right:0;z-index:1}@media (max-width:768px){body{padding:0}.true-hits{position:fixed;top:.35rem;right:0;z-index:5;margin:.25rem 1rem}}.line-clamp{display:block;display:-webkit-box;position:relative;line-height:1.4;overflow:hidden;text-overflow:ellipsis;padding:0!important}.line-clamp:after{content:"";text-align:right;bottom:0;right:0;width:25%;display:block;position:absolute;height:1.3em}@supports (-webkit-line-clamp:1){.line-clamp:after{display:none!important}}.line-clamp-1{-webkit-line-clamp:1;height:1.3em}.line-clamp-2{-webkit-line-clamp:2;height:2.6em}.line-clamp-3{-webkit-line-clamp:3;height:3.9em}.line-clamp-4{-webkit-line-clamp:4;height:5.2em}.line-clamp-5{-webkit-line-clamp:5;height:6.5em}.modal-dialog{max-width:420px;margin:0 auto}.rotate,.rotate-y{transition:all .5s linear;transform:rotate(180deg)}.paddingTop1{margin-top:1rem}.paddingTop2{margin-top:2rem}.paddingTop2 h3:first-child{color:#00b400;font-size:1.75rem}.padding-b-3{padding-bottom:3rem}.padding-t-3{padding-top:3rem}
#   </style>
#   <style>
#    @font-face{font-display:swap;font-family:cloudlight;font-style:normal;font-weight:400;src:url(/static/font/Cloud-LightBold/Cloud-Light.otf)}@font-face{font-display:swap;font-family:cloudbold;font-style:normal;font-weight:400;src:url(/static/font/Cloud-LightBold/Cloud-Bold.otf)}@font-face{font-display:swap;font-family:cloudregular;src:url(/static/font/Cloud-LightBold/cloud-regular-webfont.eot);src:url(/static/font/Cloud-LightBold/cloud-regular-webfont.eot?#iefix) format("embedded-opentype"),url(/static/font/Cloud-LightBold/cloud-regular-webfont.woff2) format("woff2"),url(/static/font/Cloud-LightBold/cloud-regular-webfont.woff) format("woff"),url(/static/font/Cloud-LightBold/cloud-regular-webfont.ttf) format("truetype"),url(/static/font/Cloud-LightBold/cloud-regular-webfont.svg#cloudregular) format("svg");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:cloudsemibold;src:url(/static/font/Cloud-LightBold/cloud-semibold-webfont.eot);src:url(/static/font/Cloud-LightBold/cloud-semibold-webfont.eot?#iefix) format("embedded-opentype"),url(/static/font/Cloud-LightBold/cloud-semibold-webfont.woff2) format("woff2"),url(/static/font/Cloud-LightBold/cloud-semibold-webfont.woff) format("woff"),url(/static/font/Cloud-LightBold/cloud-semibold-webfont.ttf) format("truetype"),url(/static/font/Cloud-LightBold/cloud-semibold-webfont.svg#cloudsemibold) format("svg");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Mn paethai v3;src:url("/static/font/MN_by_DB/MN Paethai v3.2.1.ttf") format("truetype");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Mn paethai med v3;src:url("/static/font/MN_by_DB/MN Paethai Med v3.2.1.ttf") format("truetype");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Mn paethai li v3;src:url("/static/font/MN_by_DB/MN Paethai Li v3.2.1.ttf") format("truetype");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Mn paethai demibd v3;src:url("/static/font/MN_by_DB/MN Paethai DemiBd v3.2.1.ttf") format("truetype");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Mn paethai li it v3;src:url("/static/font/MN_by_DB/MN Paethai Li It v3.2.1.ttf") format("truetype");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Mn paethai it v3;src:url("/static/font/MN_by_DB/MN Paethai It v3.2.1.ttf") format("truetype");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Mn paethai bd v3;src:url("/static/font/MN_by_DB/MN Paethai Bd v3.2.1.ttf") format("truetype");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Mn paethai bd it v3;src:url("/static/font/MN_by_DB/MN Paethai Bd It v3.2.1.ttf") format("truetype");font-weight:400;font-style:normal}@font-face{font-display:swap;font-family:Bodoni-72;src:url(/static/font/Bodoni/BodoniSvtyTwoITCTT-Book.woff2) format("woff2"),url(/static/font/Bodoni/BodoniSvtyTwoITCTT-Book.woff) format("woff");font-weight:400;font-style:normal}
#   </style>
#   <script async="" src="https://cdn.cxense.com/cx.js" type="text/javascript">
#   </script>
#   <script async="" src="https://cdn.cxense.com/cx.cce.js" type="text/javascript">
#   </script>
#   <script async="">
#    (function(d,s,e,t){e=d.createElement(s);e.type='text/java'+s;e.async='async';e.src='https://cdn.cxense.com/cx.cce.js';t=d.getElementsByTagName(s)[0];t.parentNode.insertBefore(e,t);})(document,'script');
#
#     // datalayer
#     window.dataLayer = window.dataLayer || []
#
#     // cxense analytic
#     var cX = window.cX = window.cX || {}; cX.callQueue = cX.callQueue || [];
#     cX.CCE = cX.CCE || {}; cX.CCE.callQueue = cX.CCE.callQueue || [];
#     cX.callQueue.push(['setSiteId', '1139583540649119209']);
#     cX.CCE.callQueue.push(['sendPageViewEvent']);
#
#     // byteark function
#     byteark = function() {}
#
#     // google publisher tag
#     firstLoad = true // First Request Site
#     innityLoaded = false // Innity Script Loaded
#     firstTimeInnity = false // First time call script Innity
#     googleService = false
#     contentCount = 0
#   </script>
#   <script async="" src="/static/js/prebid3.13.0-3.js">
#   </script>
#   <script async="" src="https://cdn.adnuntius.com/adn.js">
#   </script>
#   <script async="" src="https://tags.adnuntius.com/pb/thairath/thairath.co.th/mobile.js">
#   </script>
#   <meta class="next-head" content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
#   <meta charset="utf-8" class="next-head"/>
#   <script async="" class="next-head" type="application/ld+json">
#    {
# 				  "@context": "https://schema.org",
# 				  "@type": "Organization",
# 				  "name": "ไทยรัฐ สำนักข่าวอันดับ 1 ของไทย | Thairath",
# 				  "alternateName": "ไทยรัฐ  | Thairath",
# 				  "url": "https://www.thairath.co.th/",
# 				  "logo": "https://www.thairath.co.th/assets/img/icon-mythairath.png",
# 				  "contactPoint": {
# 				    "@type": "ContactPoint",
# 				    "telephone": "+662-1271222",
# 				    "email": "cs@thairath.co.th",
# 				    "contactType": "customer service"
# 				  }
# 				}
#   </script>
#   <script async="" class="next-head" type="application/ld+json">
#    {
# 				  "@context": "https://schema.org/",
# 				  "@type": "WebSite",
# 				  "name": "ไทยรัฐ สำนักข่าวอันดับ 1 ของไทย | Thairath",
# 				  "url": "https://www.thairath.co.th",
# 				  "description":"ไทยรัฐ ติดตามข่าวล่าสุด ข่าวด่วน ทันทุกเหตุการณ์ ข่าวกีฬา ผลฟุตบอล ข่าวบันเทิง ดารา สุขภาพ กิน เที่ยว ตรวจหวย ดวง คอลัมน์ เรื่องย่อละคร ดูไทยรัฐทีวี และอีกมากมายที่ thairath.co.th" ,
# 				  "sameAs": [
# 				    "https://twitter.com/Thairath_News",
# 				    "https://www.facebook.com/thairath/",
# 				    "http://line.me/ti/p/@Thairath",
# 				    "https://www.youtube.com/user/thairathonline",
# 				    "https://www.instagram.com/thairath/"
# 				  ],
# 				      "potentialAction":
# 				        {
# 				            "@type":"SearchAction",
# 				            "target":"https://www.thairath.co.th/?q={search_term_string}",
# 				            "query-input":"required name=search_term_string"
# 				        }
# 				    }
# 				  }
#   </script>
#   <link async="" class="next-head" href="//byteark-sdk.cdn.byteark.com/player/v0.5.6-thairath/byteark-player.min.css" rel="stylesheet"/>
#   <script async="" class="next-head" type="application/ld+json">
#    {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.thairath.co.th/","name":"หน้าหลัก"}},{"@type":"ListItem","position":2,"item":{"@id":"https://www.thairath.co.th/news","name":"ข่าว"}},{"@type":"ListItem","position":3,"item":{"@id":"https://www.thairath.co.th/news/business","name":"เศรษฐกิจ"}}]}
#   </script>
#   <script async="" class="next-head" type="application/ld+json">
#    {"@context":"http://schema.org","@type":"NewsArticle","headline":"ชงตั้งศูนย์ฟื้นฟูเศรษฐกิจ “บิ๊กตู่” รับข้อเสนอบูรณาการทุกส่วนกู้ประเทศ","alternativeHeadline":"ชงตั้งศูนย์ฟื้นฟูเศรษฐกิจ “บิ๊กตู่” รับข้อเสนอบูรณาการทุกส่วนกู้ประเทศ","image":["https://www.thairath.co.th/media/dFQROr7oWzulq5FZUECroFFdX5kBhiSY2Xdz8F80X5zqmHQNLTOzWnbJ2caLHjezk7C.jpg"],"datePublished":"2020-07-11T07:01:00+07:00","description":"นายกฯเปิดเวทีหารือทีมที่ปรึกษาเศรษฐกิจชุดใหญ่ รับข้อเสนอตั้งศูนย์ฟื้นฟูเศรษฐกิจ รูปแบบเดียวกับ ศบค.พร้อมชงให้นายกฯนั่งเป็นประธาน เพื่อให้บูรณาการระหว่างหน่วยงาน","articleBody":"นายกฯเปิดเวทีหารือทีมที่ปรึกษาเศรษฐกิจชุดใหญ่ รับข้อเสนอตั้งศูนย์ฟื้นฟูเศรษฐกิจ รูปแบบเดียวกับ ศบค.พร้อมชงให้นายกฯนั่งเป็นประธาน เพื่อให้บูรณาการระหว่างหน่วยงาน พร้อมหามาตรการช่วยเอสเอ็มอีเข้าถึงเงินทุนให้ได้ เอกชนถามกลางที่ประชุมห่วงสถานการณ์การเมือง คลุมเครือ หวั่นข้าราชการเกียร์ว่าง ด้านสภาธุรกิจตลาดทุน ขอนายกฯ เร่งตั้งตลาดหุ้น SME หวังช่วยกลุ่มธุรกิจรายย่อยเข้มแข็ง\r\nผู้สื่อข่าวรายงานจากทำเนียบรัฐบาลว่า พล.อ.ประยุทธ์ จันทร์โอชา นายกรัฐมนตรี ได้เป็นประธานการประชุมหารือแนวทางการช่วยเหลือและฟื้นฟูเศรษฐกิจจากการแพร่ระบาดของโรคติดเชื้อไวรัสโคโรนา 2019 (โควิด-19) โดยมีวาระการหารือเรื่อง 1.รายงานสถานการณ์เศรษฐกิจ และกรอบการขับเคลื่อนเศรษฐกิจไทยในช่วงที่เหลือของปี 63 2. การช่วยเหลือและฟื้นฟูวิสาหกิจขนาดกลางและขนาดย่อม (SMEs) ที่ได้รับผลกระทบจาก Covid-19 โดยมีนายสมคิด จาตุศรีพิทักษ์ รองนายกรัฐมนตรี นายอุตตม สาวนายน รมว.คลัง และนายกอบศักดิ์ ภูตระกูล รองเลขาธิการนายกรัฐมนตรีฝ่ายการเมืองและเลขานุการคณะรัฐมนตรีฝ่ายเศรษฐกิจเข้าร่วม\r\nโดยนายกอบศักดิ์ เผยภายหลังการประชุมว่า นายกฯแจ้งว่าการประชุมทีมที่ปรึกษาเศรษฐกิจครั้งนี้เป็นรูปแบบใหม่ แบบนิว นอร์มอล ที่มีการหารือกับทุกภาคส่วน และจะนำข้อเสนอแนะไปพิจารณาประกอบดับข้อกฎหมายและงบประมาณ บางเรื่องจะส่งต่อให้กระทรวงที่เกี่ยวข้องนำเข้าที่ประชุมคณะรัฐมนตรี (ครม.) หรือบางเรื่องนำไปเข้า ครม.เศรษฐกิจก่อน โดยมีประเด็นสำคัญในครั้งนี้ ที่ภาคเอกชนเสนอให้รัฐบาล จัดตั้งศูนย์ฟื้นฟูเศรษฐกิจจากการระบาดของเชื้อไวรัสโคโรนา 2019 (โควิด-19) มีรูปแบบการปฏิบัติงานเช่นเดียวกันศูนย์บริหารสถานการณ์การแพร่ระบาดของโรคติดเชื้อไวรัสโคโรนา 2019 
เนียมสูงๆให้แพลตฟอร์มต่างประเทศ\r\nนายกลินท์ สารสิน ประธานสภาหอการค้าแห่งประเทศไทย กล่าวว่า เอกชนเป็นห่วงในเรื่องของสถานการณ์การเมืองที่ไม่แน่นอน ความคลุมเครือโดยเฉพาะการลาออกของ 4 กุมาร ที่แม้จะยังอยู่ในตำแหน่งรัฐมนตรี แต่ไม่ได้อยู่ในพรรคแล้ว อาจทำให้ข้าราชการเกียร์ว่าง ซึ่งเอกชนก็ ...
#   </script>
#   <title>
#    ชงตั้งศูนย์ฟื้นฟูเศรษฐกิจ “บิ๊กตู่” รับข้อเสนอบูรณาการทุกส่วนกู้ประเทศ
#   </title>
#   <meta class="next-head" content="2020-07-11T07:01:00+07:00" http-equiv="last-modified"/>
#   <meta class="next-head" content="2020-07-11T00:01:00Z" itemprop="datePublished"/>
#   <script async="" class="next-head">
#    window._vwo_code = window._vwo_code || (function(){
# 						var account_id=280223,
# 						settings_tolerance=2000,
# 						library_tolerance=2500,
# 						use_existing_jquery=false,
# 						is_spa=1,
# 						hide_element='body',/* DO NOT EDIT BELOW THIS LINE */
# 						f=false,d=document,code={use_existing_jquery:function(){return use_existing_jquery;},library_tolerance:function(){return library_tolerance;},finish:function(){if(!f){f=true;var a=d.getElementById('_vis_opt_path_hides');if(a)a.parentNode.removeChild(a);}},finished:function(){return f;},load:function(a){var b=d.createElement('script');b.src=a;b.type='text/javascript';b.innerText;b.onerror=function(){_vwo_code.finish();};d.getElementsByTagName('head')[0].appendChild(b);},init:function(){
# 						window.settings_timer=setTimeout('_vwo_code.finish()',settings_tolerance);var a=d.createElement('style'),b=hide_element?hide_element+'{opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important;}':'',h=d.getElementsByTagName('head')[0];a.setAttribute('id','_vis_opt_path_hides');a.setAttribute('type','text/css');if(a.styleSheet)a.styleSheet.cssText=b;else a.appendChild(d.createTextNode(b));h.appendChild(a);this.load('https://dev.visualwebsiteoptimizer.com/j.php?a='+account_id+'&u='+encodeURIComponent(d.URL)+'&f='+(+is_spa)+'&r='+Math.random());return settings_timer; }};window._vwo_settings_timer = code.init(); return code; }());
#   </script>
#   <script src="https://dev.visualwebsiteoptimizer.com/j.php?a=280223&amp;u=https%3A%2F%2Fwww.thairath.co.th%2Fnews%2Fbusiness%2F1886753&amp;f=1&amp;r=0.14580503945843493" type="text/javascript">
#   </script>
#   <link as="script" href="/_next/static/j4LkPMzBFyp8FJ10PgWJc/pages/content/view.js" rel="preload"/>
#   <link as="script" href="/_next/static/j4LkPMzBFyp8FJ10PgWJc/pages/_app.js" rel="preload"/>
#   <link as="script" href="/_next/static/runtime/webpack-e52544d3f5a311794eae.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/commons.dc98279090bada6217b5.js" rel="preload"/>
#   <link as="script" href="/_next/static/runtime/main-ebcf269cdbaea505a027.js" rel="preload"/>
#   <script crossorigin="anonymous" src="https://dev.visualwebsiteoptimizer.com/6.0/va-ca976d0c9e34ce141287fe8917e41767.js" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" src="https://dev.visualwebsiteoptimizer.com/6.0/track-ca976d0c9e34ce141287fe8917e41767.js" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" src="https://dev.visualwebsiteoptimizer.com/analysis/3.0/opa-a4111607dc5ce718c2993c75e25e5d78.js" type="text/javascript">
#   </script>
#  </head>
#  <body>
#   <div class="true-hits hidden">
#    <div id="truehits_div">
#    </div>
#   </div>
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WK2N7MN" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div id="__next">
#    <main>
#     <style data-emotion-css="18xcx45">
#      .css-18xcx45{max-width:100%;}.css-18xcx45 .container{max-width:1140px;position:relative;}.css-18xcx45 .BgBlackFull{background:#000;width:100%;max-width:unset;}.css-18xcx45 .BgGrayFull{background:#f2f2f2;width:100%;max-width:unset;}.css-18xcx45 .PaddingNone{padding:0;}
#     </style>
#     <div class="css-18xcx45 efr6tej1">
#      <style data-emotion-css="6egl3g">
#       .css-6egl3g{position:fixed;top:0;width:100%;-webkit-transition:-webkit-transform 0.5s ease-out;-webkit-transition:-webkit-transform 0.5s ease-out;-webkit-transition:-webkit-transform 0.5s ease-out;transition:-webkit-transform 0.5s ease-out;-o-transition:transform 0.5s ease-out;-webkit-transition:-webkit-transform 0.5s ease-out;-webkit-transition:transform 0.5s ease-out;transition:transform 0.5s ease-out;-webkit-transition:-webkit-transform 0.5s ease-out,-webkit-transform 0.5s ease-out;-webkit-transition:transform 0.5s ease-out,-webkit-transform 0.5s ease-out;transition:transform 0.5s ease-out,-webkit-transform 0.5s ease-out;-webkit-transform:translate3d(0,-0px,550px) !important;-ms-transform:translate3d(0,-0px,550px) !important;transform:translate3d(0,-0px,550px) !important;z-index:999;}
#      </style>
#      <div class="css-6egl3g e8s9vs6" id="headerWraper" transform="0">
#       <style data-emotion-css="8hnfdp">
#        .css-8hnfdp{position:relative;text-align:center;background-color:#ffffff;display:grid;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 0 15px;height:0px;padding:0 0;}.css-8hnfdp .adBox{display:inline;}.css-8hnfdp #slot-billboard:nth-of-type(1){margin:0 auto;}.css-8hnfdp iframe{min-height:auto !important;}@media (max-width:768px){.css-8hnfdp{margin-bottom:0rem;}}
#       </style>
#       <div class="css-8hnfdp e160b0jq7">
#       </div>
#       <style data-emotion-css="1ymkx1j">
#        .css-1ymkx1j{position:relative;text-align:center;background-color:#ffffff;display:grid;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 0 15px;-webkit-animation-name:example;animation-name:example;-webkit-animation-duration:0.5s;animation-duration:0.5s;}.css-1ymkx1j .adBox{display:inline;}.css-1ymkx1j #slot-billboard:nth-of-type(1){margin:0 auto;}@-webkit-keyframes example{0%{-webkit-transform:scale(1) translate(-0%,-120%);-ms-transform:scale(1) translate(-0%,-120%);transform:scale(1) translate(-0%,-120%);-moz-transition:transform 0.5s ease-in-out;-o-transition:transform 0.5s ease-in-out;-webkit-transition:transform 0.5s ease-in-out;-webkit-transition:-webkit-transform 0.5s ease-in-out;-webkit-transition:transform 0.5s ease-in-out;transition:transform 0.5s ease-in-out;}100%{-webkit-transform:scale(1) translate(-0%,-1%);-ms-transform:scale(1) translate(-0%,-1%);transform:scale(1) translate(-0%,-1%);-moz-transition:transform 0.5s ease-in-out;-o-transition:transform 0.5s ease-in-out;-webkit-transition:transform 0.5s ease-in-out;-webkit-transition:-webkit-transform 0.5s ease-in-out;-webkit-transition:transform 0.5s ease-in-out;transition:transform 0.5s ease-in-out;}}@keyframes example{0%{-webkit-transform:scale(1) translate(-0%,-120%);-ms-transform:scale(1) translate(-0%,-120%);transform:scale(1) translate(-0%,-120%);-moz-transition:transform 0.5s ease-in-out;-o-transition:transform 0.5s ease-in-out;-webkit-transition:transform 0.5s ease-in-out;-webkit-transition:-webkit-transform 0.5s ease-in-out;-webkit-transition:transform 0.5s ease-in-out;transition:transform 0.5s ease-in-out;}100%{-webkit-transform:scale(1) translate(-0%,-1%);-ms-transform:scale(1) translate(-0%,-1%);transform:scale(1) translate(-0%,-1%);-moz-transition:transform 0.5s ease-in-out;-o-transition:transform 0.5s ease-in-out;-webkit-transition:transform 0.5s ease-in-out;-webkit-transition:-webkit-transform 0.5s ease-in-out;-webkit-transition:transform 0.5s ease-in-out;transition:transform 0.5s ease-in-out;}}.css-1ymkx1j iframe{min-height:auto !important;}@media (max-width:768px){.css-1ymkx1j{margin-bottom:0rem;}}
#       </style>
#       <div class="hidden css-1ymkx1j e160b0jq7">
#        <div style="text-align:center">
#        </div>
#       </div>
#       <style data-emotion-css="14hpk09">
#        body{font-family:"cloudregular";-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;padding-top:75px;}body a{font-family:"cloudregular";color:#01b400;-webkit-transition:all 0.3s;transition:all 0.3s;}body h1,body h2,body h3,body h4,body h5,body h6{font-family:"cloudsemibold";font-weight:inherit;}
#       </style>
#       <style data-emotion-css="lgbevb">
#        @media (max-width:768px){body{padding-top:50px;}}
#       </style>
#       <style data-emotion-css="1vs7tnd">
#        .css-1vs7tnd{background:#fff;height:55px;}.css-1vs7tnd .container{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;}.css-1vs7tnd .collapse:not(.show){display:none;}
#       </style>
#       <header class="css-1vs7tnd e8s9vs7" id="headerMenu">
#        <div class="container">
#         <style data-emotion-css="1c2xxt9">
#          .css-1c2xxt9{z-index:1;width:110px;margin-right:1rem;display:grid;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.css-1c2xxt9 img{max-width:100%;}.css-1c2xxt9 a{display:grid;}@media (max-width:767px){.css-1c2xxt9{width:100%;margin-right:-15px;display:grid;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;
#              </path>
#              <path d="M960.656,342.377h-1.344v-7.411c0-1.448,1.323-1.716,1.323-2.647,0-.187,0-.6-.476-.6h-2.832v-1.2h2.832c1.8,0,1.82.972,1.82,1.7,0,1.489-1.323,1.531-1.323,2.75Z" data-name="Path 7791" fill="#00b400" id="Path_7791" transform="translate(-884.116 -303.47)">
#              </path>
#              <path d="M966.524,338.5a7.631,7.631,0,0,1,2.253.228v-1.468c0-1.034-.889-1.137-1.9-1.137s-1.9.1-1.9,1.137v.413h-1.344v-.413c0-1.674,1.241-2.336,3.246-2.336s3.246.662,3.246,2.336V343.3h-1.344v-2.853c0-.745-1.365-.745-2.233-.745-.91,0-1.8.187-1.8,1.075,0,1.117,0,1.323,1.489,1.323h.29v1.2h-.682c-2.3,0-2.316-1.24-2.316-2.481C963.525,339.1,964.683,338.5,966.524,338.5Z" data-name="Path 7792" fill="#00b400" id="Path_7792" transform="translate(-885.414 -304.393)">
#              </path>
#              <path d="M975.226,335.056v5.562c0,1.075.682,1.613,1.778,1.613,1.221,0,2.151-.6,2.151-1.613v-5.562H980.5v8.271h-1.344v-1.013a2.334,2.334,0,0,1-2.233,1.116c-2.192,0-3.04-1.116-3.04-2.812v-5.562Z" data-name="Path 7793" fill="#00b400" id="Path_7793" transform="translate(-887.583 -304.42)">
#              </path>
#              <path d="M979.007,330.521h3.515v1.1h-2.315v.786h-1.2Z" data-name="Path 7794" fill="#00b400" id="Path_7794" transform="translate(-888.656 -303.47)">
#              </path>
#             </g>
#            </g>
#           </svg>
#          </a>
#         </div>
#         <style data-emotion-css="a8c9fk">
#          .css-a8c9fk{-webkit-flex:auto;-ms-flex:auto;flex:auto;width:0;}.css-a8c9fk a{color:#000000;-webkit-transition:all 0.3s;transition:all 0.3s;}.css-a8c9fk a:hover{-webkit-transition:all 0.3s;transition:all 0.3s;color:#008841;}@media (max-width:767px){.css-a8c9fk{display:none;}}
#         </style>
#         <nav class="css-a8c9fk e8s9vs3">
#          <style data-emotion-css="1ltqhy5">
#           .css-1ltqhy5{display:-ms-flexbox;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-ms-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;font-weight:100;padding-left:0;margin-bottom:0;list-style:none;margin-top:0;}.css-1ltqhy5 li:nth-of-type(12){display:none;}@media (max-width:800px){.css-1ltqhy5 li:nth-of-type(n + 7){display:none;}}@media (max-width:880px){.css-1ltqhy5 li:nth-of-type(n + 8){display:none;}}@media (max-width:940px){.css-1ltqhy5 li:nth-of-type(n + 10){display:none;}}@media (max-width:1000px){.css-1ltqhy5 li:nth-of-type(n + 11){display:none;}}@media (max-width:1100px){.css-1ltqhy5 li:nth-of-type(n + 12){display:none;}}@media (max-width:1199px){.css-1ltqhy5 li:nth-of-type(n + 13){display:none;}}@media (max-width:991px){.css-1ltqhy5 li{display:none;}.css-1ltqhy5 #isProfile{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}}
#          </style>
#          <ul class="css-1ltqhy5 e8s9vs4">
#           <style data-emotion-css="1t6yorp">
#            .css-1t6yorp{padding:0 7px;height:55px;line-height:55px;font-family:"cloudregular";font-size:1.2rem;}@media (max-width:768px){.css-1t6yorp{padding:0px;}.css-1t6yorp:not(:nth-of-type(1)){display:none;}}@media (min-width:1181px) and (max-width:1439px){.css-1t6yorp{font-size:1.1rem;}}.css-1t6yorp .submenu{display:none;}.css-1t6yorp:hover .submenu{display:block;top:55px;border:1px solid #E5E5E5;background:#fff;padding-bottom:0.5rem;}.css-1t6yorp:nth-of-type(5){display:none;}
#           </style>
#           <li class="css-1t6yorp eievgs3">
#            <a href="/news">
#             ข่าว
#            </a>
#            <style data-emotion-css="1k0niue">
#             .css-1k0niue{position:absolute;font-size:0.9rem;min-width:10rem;}
#            </style>
#            <div class="submenu css-1k0niue eievgs4">
#             <style data-emotion-css="y8aj3r">
#              .css-y8aj3r{padding:0;}
#             </style>
#             <ul class="css-y8aj3r eievgs5">
#              <style data-emotion-css="1qlshtt">
#               .css-1qlshtt{padding:0rem 1rem;list-style:none;margin-bottom:-10px;font-size:1.2rem;}
#              </style>
#              <li class="css-1qlshtt eievgs6">
#               <a href="/news/royal">
#                พระราชสำนัก
#               </a>
#              </li>
#              <li class="css-1qlshtt eievgs6">
#               <a href="/news/local">
#                ทั่วไทย
#               </a>
#              </li>
#              <li class="css-1qlshtt eievgs6">
#               <a href="https://www.thairath.co.th/news/business">
#                เศรษฐกิจ
#               </a>
#              </li>
#              <li class="css-1qlshtt eievgs6">
#               <a href="/news/gold">
#                ราคาทองคำ
#               </a>
#              </li>
#              <li class="css-1qlshtt eievgs6">
#               <a href="/news/foreign">
#                ต่างประเทศ
#               </a>
#              </li>
#              <li class="css-1qlshtt eievgs6">
#               <a href="/news/politic">
#                การเมือง
#               </a>
#              </li>
#              <li class="css-1qlshtt eievgs6">
#               <a href="/news/society">
#                สังคม
#               </a>
#              </li>
#              <li class="css-1qlshtt eievgs6">
#               <a href="/news/crime">
#                อาชญากรรม
#               </a>
#              </li>
#              <li class="css-1qlshtt eievgs6">
#               <a href="/news/auto">
#                ยานยนต์
#               </a>
#              </li>
#              <li class="css-1qlshtt eievgs6">
#               <a href="/news/tech">
#                Tech
#               </a>
#              </li>
#             </ul>
#            </div>
#           </li>
#           <li class="css-1t6yorp eievgs3">
#            <a href="https://www.thairath.co.th/newspaper">
#             หนังสือพิมพ์
#            </a>
#           </li>
#           <li class="css-1t6yorp eievgs3">
#            <a href="https://www.thairath.co.th/tv">
# ...
#               </path>
#               <path d="M1001.75,541.35v3.82a1.532,1.532,0,0,0,.31,1.08,1.07,1.07,0,0,0,.82.32,1.424,1.424,0,0,0,1.12-.54,2.484,2.484,0,0,0,.46-1.62v-3.06h1.02v4.16c0,.22,0,.41.01.57s.01.32.02.46.02.28.04.41.03.26.05.4h-1.04c-.03-.16-.05-.3-.07-.43s-.02-.26-.03-.4a2.591,2.591,0,0,1-.79.69,2.107,2.107,0,0,1-1.06.26,2.191,2.191,0,0,1-.73-.12,1.468,1.468,0,0,1-.59-.38,1.993,1.993,0,0,1-.4-.69,3.133,3.133,0,0,1-.15-1.04v-3.89h1.01Z" data-name="Path 22">
#               </path>
#               <path d="M1004.38,539.59a1.563,1.563,0,0,0-.42.04.494.494,0,0,0-.24.15.588.588,0,0,0-.11.29,2.888,2.888,0,0,0-.02.44h-.96a5.046,5.046,0,0,1,.06-.85,1.247,1.247,0,0,1,.23-.56.964.964,0,0,1,.5-.3,3.411,3.411,0,0,1,.87-.09h1.69l-.38.88Z" data-name="Path 23">
#               </path>
#              </g>
#             </g>
#            </g>
#           </svg>
#           <style data-emotion-css="1clzs2j">
#            .css-1clzs2j{grid-column:span 2;margin-top:22px;margin-bottom:8px;}.css-1clzs2j a{font-size:1rem;line-height:1.25rem;font-size:16px;color:#626262;margin-right:18px;-webkit-transition:all 0.3s;transition:all 0.3s;}.css-1clzs2j a:hover{color:#00b400;-webkit-transition:all 0.3s;transition:all 0.3s;}.css-1clzs2j a svg ellipse,.css-1clzs2j a svg path{fill:#00B400;-webkit-transition:all 0.3s;transition:all 0.3s;}.css

#              </path>
#             </svg>
#            </a>
#            <a href="https://www.youtube.com/user/thairathonline" rel="noopener" target="_blank">
#             <svg height="15.774" viewbox="0 0 22.435 15.774" width="22.435">
#              <path d="M36.9,66.468a2.819,2.819,0,0,0-1.983-2C33.166,64,26.15,64,26.15,64s-7.016,0-8.765.472a2.819,2.819,0,0,0-1.983,2,31.74,31.74,0,0,0,0,10.87A2.777,2.777,0,0,0,17.385,79.3c1.75.472,8.765.472,8.765.472s7.016,0,8.765-.472A2.777,2.777,0,0,0,36.9,77.338a31.74,31.74,0,0,0,0-10.87ZM23.856,75.239V68.567L29.719,71.9Z" fill="#8b8b8b" id="youtube-brands-5" transform="translate(-14.933 -64)">
#              </path>
#             </svg>
#            </a>
#            <a href="https://www.thairath.co.th/rss/news" target="_blank">
#             <svg height="15.504" viewbox="0 0 15.504 15.504" width="15.504">
#              <ellipse cx="2.112" cy="2.112" data-name="Ellipse 9" fill="#8b8b8b" id="Ellipse_9" rx="2.112" ry="2.112" transform="translate(0 11.279)">
#              </ellipse>
#              <path d="M4,4.44V7.26A12.685,12.685,0,0,1,16.684,19.944H19.5A15.508,15.508,0,0,0,4,4.44Zm0,5.64V12.9a7.05,7.05,0,0,1,7.044,7.044h2.82A9.861,9.861,0,0,0,4,10.08Z" data-name="Path 6" fill="#8b8b8b" id="Path_6" transform="translate(-4 -4.44)">
#              </path>
#             </svg>
#            </a>
#            <a href="https://www.thairath.co.th/tv" target="_blank">
#             <svg height="15.961" viewbox="0 0 19.506 15.961" width="19.506">
#              <path d="M285.734-37.5H269.774A1.767,1.767,0,0,0,268-35.74v10.653a1.773,1.773,0,0,0,1.772,1.774h4.434v1.774H281.3v-1.774h4.433a1.771,1.771,0,0,0,1.764-1.774l.009-10.641A1.773,1.773,0,0,0,285.734-37.5Zm0,12.414H269.774v-10.64h15.961Z" data-name="Path 306" fill="#8b8b8b" id="Path_306" transform="translate(-268 37.5)">
#              </path>
#             </svg>
#            </a>
#           </div>
#           <style data-emotion-css="100nxfx">
#            .css-100nxfx{display:grid;grid-template-columns:1fr 1fr 1fr 1fr;display:block;grid-column:span 2;grid-template-columns:100%;}.css-100nxfx ul{margin:0;padding:0;border-left:1px solid #D1D1D1;}.css-100nxfx ul li{margin:0 0 3px 0;padding:0 25px;list-style:none;}.css-100nxfx ul li a{color:#626262;position:relative;display:inline-block;font-size:1rem;line-height:1.25rem;-webkit-transition:all 0.3s;transition:all 0.3s;}.css-100nxfx ul li a:hover{color:#00B400;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:all 0.3s;transition:all 0.3s;}.css-100nxfx ul li:last-of-type{margin-bottom:0;}.css-100nxfx ul:last-of-type{border-right:1px solid #D1D1D1;}.css-100nxfx a{margin-right:12px;}.css-100nxfx a:hover{color:#00B400;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:all 0.3s;transition:all 0.3s;}@media (min-width:992px){.css-100nxfx{grid-column:span 2;}}@media (max-width:1199.98px){.css-100nxfx ul li{padding:0 20px;}}
#           </style>
#           <div class="css-100nxfx eh8v0mb7">
#            <a href="https://www.thairath.co.th/ads" target="_blank">
#             ติดต่อโฆษณา
#            </a>
#            <a href="https://www.thairath.co.th/job/recruit" target="_blank">
#             ร่วมงานกับเรา
#            </a>
#            <a href="/contact_th" target="_blank">
#             ติดต่อเรา
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <style data-emotion-css="2fbxhu">
#        .css-2fbxhu{position:relative;padding:10px 0;background-color:#00b400;}.css-2fbxhu a{color:#FFF;line-height:22px;padding:0 5px;}.css-2fbxhu a:hover{color:#690;}@media (max-width:992px){.css-2fbxhu a{line-height:20px;}.css-2fbxhu small{font-size:11px;}.css-2fbxhu .box-social{padding:1rem 0 0.5rem 0;margin-top:0.5rem;border-top:1px dotted #333;}}
#       </style>
#       <div class="css-2fbxhu eh8v0mb13">
#        <div class="container">
#         <style data-emotion-css="tuywv7">
#          .css-tuywv7{position:relative;text-align:center;}.css-tuywv7 small a:hover{color:#FFF !important;-webkit-text-decoration:underline;text-decoration:underline;}@media (min-width:768px) and (max-width:1199px){.css-tuywv7{display:block;text-align:center;padding:0;}}.css-tuywv7 .eh8v0mb1{font-size:14px;-webkit-transition:all 0.3s;transition:all 0.3s;}.css-tuywv7 .eh8v0mb1 a{color:#FFF;-webkit-transition:all 0.3s;transition:all 0.3s;}.css-tuywv7 .eh8v0mb1:hover a{-webkit-transition:all 0.3s;transition:all 0.3s;color:#000;}@media (min-width:1200px) and (max-width:1399px){.css-tuywv7 .eh8v0mb1{padding-right:0;}}@media (max-width:1199.98px){.css-tuywv7{grid-template-columns:1fr 440px 1fr;}}@media (max-width:767px){.css-tuywv7{display:block;}}
#         </style>
#         <div class="css-tuywv7 eh8v0mb2">
#          <style data-emotion-css="1kuy7z7">
#           .css-1kuy7z7{font-size:14px;}
#          </style>
#          <small class="css-1kuy7z7 eh8v0mb1">
#           <a href="https://www.thairath.co.th/corporate/generation1" target="_blank">
#            เกี่ยวกับไทยรัฐ
#           </a>
#          </small>
#          <small class="css-1kuy7z7 eh8v0mb1">
#           <a href="http://www.thairath-found.or.th/" rel="noopener" target="_blank">
#            มูลนิธิไทยรัฐ
#           </a>
#          </small>
#          <small class="css-1kuy7z7 eh8v0mb1">
#           <a href="https://www.thairath.co.th/datacenter/" target="_blank">
#            ศูนย์ข้อมูลไทยรัฐ
#           </a>
#          </small>
#          <small class="css-1kuy7z7 eh8v0mb1">
#           <a href="https://www.thairath.co.th/info/sms" target="_blank">
#            บริการข่าวไทยรัฐ - App &amp; SMS
#           </a>
#          </small>
#          <small class="css-1kuy7z7 eh8v0mb1">
#           <a href="https://www.thairath.co.th/faq/" target="_blank">
#            FAQ
#           </a>
#          </small>
#          <small class="css-1kuy7z7 eh8v0mb1">
#           <a href="https://www.thairath.co.th/assets/thairath-privacy-policy-2018-02.pdf" target="_blank">
#            นโยบายความเป็นส่วนตัว
#           </a>
#          </small>
#          <small class="css-1kuy7z7 eh8v0mb1">
#           <a href="https://www.thairath.co.th/assets/thairath-terms-condition-2018-02.pdf" target="_blank">
#            เงื่อนไขข้อตกลงการใช้บริการ
#           </a>
#          </small>
#         </div>
#        </div>
#       </div>
#      </footer>
#     </div>
#    </main>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"dataManager":"[]","props":{"isServer":true,"initialState":{"common":{"data":{"id":1886753,"title":"ชงตั้งศูนย์ฟื้นฟูเศรษฐกิจ “บิ๊กตู่” รับข้อเสนอบูรณาการทุกส่วนกู้ประเทศ","fullPath":"/news/business/1886753","topicPath":"/news/business","canonical":"https://www.thairath.co.th/news/business/1886753","sectionName":"news","tags":["ฟื้นฟูเศรษฐกิจ","ทีมเศรษฐกิจชุดใหญ่","ตลาดหุ้น SME","ประยุทธ์ จันทร์โอชา","กลินท์ สารสิน","SME","ข่าววันนี้"],"topicName":"business","credit":"ไทยรัฐฉบับพิมพ์","image":"https://www.thairath.co.th/media/dFQROr7oWzulq5FZUECroFFdX5kBhiSY2Xdz8F80X5zqmHQNLTOzWnbJ2caLHjezk7C.jpg","keywords":["ฟื้นฟูเศรษฐกิจ","ทีมเศรษฐกิจชุดใหญ่","ตลาดหุ้น SME","ประยุทธ์ จันทร์โอชา","กลินท์ สารสิน","SME","ข่าววันนี้"],"description":"นายกฯเปิดเวทีหารือทีมที่ปรึกษาเศรษฐกิจชุดใหญ่ รับข้อเสนอตั้งศูนย์ฟื้นฟูเศรษฐกิจ รูปแบบเดียวกับ ศบค.พร้อมชงให้นายกฯนั่งเป็นประธาน เพื่อให้บูรณาการระหว่างหน่วยงาน","partner":{"isPartner":false,"partnersource":null},"sourceFrom":"print","lastModified":"2020-07-11T07:01:00+07:00","imageSML":{"small":"https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxaTNKT.jpg","medium":"https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxYTsqk.jpg","large":"https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxdO3Ya.jpg"},"entityType":5,"publishTime":"2020-07-11T07:01:00+07:00","contentarea":null},"adsSetting":{"isBillboard":false,"isUnderlay":false,"isBalloon":true,"isLightbox":true,"isPreroll":true,"isTakeOver":false,"isOpen":true},"linkedData":{"dataLinks":["https://www.thairath.co.th/news/business/1886753"],"imageLinks":["https://www.thairath.co.th/media/dFQROr7oWzulq5FZUECroFFdX5kBhiSY2Xdz8F80X5zqmHQNLTOzWnbJ2caLHjezk7C.jpg"],"galleryLinks":[]},"minTs":1594425660,"page":"content","statusCode":200},"home":{"data":[],"isLoading":false,"statusCode":[]},"content":{"data":{"items":{"id":1886753,"title":"ชงตั้งศูนย์ฟื้นฟูเศรษฐกิจ “บิ๊กตู่” รับข้อเสนอบูรณาการทุกส่วนกู้ประเทศ","type":1,"sourceFrom":"print","entityType":5,"sectionId":"58bcd80235528f1c9c000c30","section":"ข่าว","sectionEn":"news","topicId":"58bcd80235528f1c9c000c3a","topic":"เศรษฐกิจ","topicEn":"business","contentarea":null,"contentareaEn":null,"topicPath":"/news/business","fullPath":"/news/business/1886753","categoryName":null,"categoryNameEn":null,"categoryFullPath":null,"categoryFullPathTh":null,"breadcrumb":[{"page":"หน้าหลัก","link":"/"},{"page":"ข่าว","link":"/news"},{"page":"เศรษฐกิจ","link":"/news/business"}],"thumbnail":{"EntityType":22,"display":"https://www.thairath.co.th/media/dFQROr7oWzulq5FZUECroFFdX5kBhiSY2Xdz8F80X5zqmHQNLTOzWnbJ2caLHjezk7C.jpg","video":null,"image":"\u003cpicture\u003e\n  \u003csource srcset=\"https://www.thairath.co.th/media/dFQROr7oWzulq5FZUECroFFdX5kBhiSY2Xdz8F80X5zqmHQNLTOzWnbJ2caLHjezk7C.webp\" type=\"image/webp\"\u003e\n  \u003csource srcset=\"https://www.thairath.co.th/media/dFQROr7oWzulq5FZUECroFFdX5kBhiSY2Xdz8F80X5zqmHQNLTOzWnbJ2caLHjezk7C.jpg\" type=\"image/jpeg\"\u003e \n  \u003cimg src=\"https://www.thairath.co.th/media/dFQROr7oWzulq5FZUECroFFdX5kBhiSY2Xdz8F80X5zqmHQNLTOzWnbJ2caLHjezk7C.jpg\" alt=\"\"\u003e\n\u003c/picture\u003e","shareImage":"https://www.thairath.co.th/media/dFQROr7oWzulq5FZUECroFFdX5kBhiSY2Xdz8F80X5zqmHQNLTOzWnbJ2caLHjezk7C.jpg","imageSML":{"small":"https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxaTNKT.jpg","medium":"https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxYTsqk.jpg","large":"https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxdO3Ya.jpg"}},"abstract":"นายกฯเปิดเวทีหารือทีมที่ปรึกษาเศรษฐกิจชุดใหญ่ รับข้อเสนอตั้งศูนย์ฟื้นฟูเศรษฐกิจ รูปแบบเดียวกับ ศบค.พร้อมชงให้นายกฯนั่งเป็นประธาน เพื่อให้บูรณาการระหว่างหน่วยงาน","image":"https://www.thairath.co.th/media/dFQROr7oWzulq5FZUECroFFdX5kBhiSY2Xdz8F80X5zqmHQNLTOzWnbJ2caLHjezk7C.jpg","imageSML":{"small":"https://www.thairath.co.th/media/4DQpjUtzLUwmJZZO8slAMxK91N5BKgmMLgq13FxaTNKT.jpg","medium":"https://www.thairath.c ...
#   </script>
#   <script async="" id="__NEXT_PAGE__/content/view" src="/_next/static/j4LkPMzBFyp8FJ10PgWJc/pages/content/view.js">
#   </script>
#   <script async="" id="__NEXT_PAGE__/_app" src="/_next/static/j4LkPMzBFyp8FJ10PgWJc/pages/_app.js">
#   </script>
#   <script async="" src="/_next/static/runtime/webpack-e52544d3f5a311794eae.js">
#   </script>
#   <script async="" src="/_next/static/chunks/commons.dc98279090bada6217b5.js">
#   </script>
#   <script async="" src="/_next/static/runtime/main-ebcf269cdbaea505a027.js">
#   </script>
#   <iframe frameborder="0" height="1" id="cx_rep_iframe_0.11771089943336666" name="cx_rep_iframe_0.11771089943336666" scrolling="no" src="https://scdn.cxense.com/sp1.html#ver=1&amp;typ=pgv&amp;rnd=kcj77uw95lu6ic31&amp;acc=0&amp;sid=1139583540649119209&amp;loc=https%3A%2F%2Fwww.thairath.co.th%2Fnews%2Fbusiness%2F1886753&amp;ref=&amp;gol=&amp;pgn=&amp;ltm=1594565651241&amp;new=0&amp;arf=0&amp;tzo=-120&amp;res=2560x1440&amp;dpr=1.5&amp;col=24&amp;jav=0&amp;bln=en-US&amp;cks=kcj77uwkv36jgb7o&amp;ckp=kcj77uwfddd4rijo&amp;glb=&amp;chs=UTF-8&amp;wsz=1251x1227&amp;amo=1594425660&amp;cp_ver=2.32&amp;cp_testGroup=94&amp;fls=0&amp;flv=" style="display: none;" width="1">
#   </iframe>
#  </body>
# </html>

# %%
soup.find('meta', property='article:published_time')['content']
# Out:
# '2020-07-11T07:01:00+07:00'

# %%
from datetime import datetime
t = datetime.strptime(soup.find('meta', property='article:published_time')['content'][:-6], '%Y-%m-%dT%H:%M:%S')
print(t.strftime('%Y-%m-%d'))
# Out:
# 2020-07-11

# %%
tags = soup.find('h2', text='แท็กที่เกี่ยวข้อง').find_next('div').find_all('span')
tags[0].text
# Out:
# 'ฟื้นฟูเศรษฐกิจ'

# %%
contents = soup.find('article', id='article-content').find_all('p')

contents
# Out:
# [<p><strong>นายกฯเปิดเวทีหารือทีมที่ปรึกษาเศรษฐกิจชุดใหญ่ รับข้อเสนอตั้งศูนย์ฟื้นฟูเศรษฐกิจ</strong> รูปแบบเดียวกับ ศบค.พร้อมชงให้นายกฯนั่งเป็นประธาน เพื่อให้บูรณาการระหว่างหน่วยงาน พร้อมหามาตรการช่วยเอสเอ็มอีเข้าถึงเงินทุนให้ได้ เอกชนถามกลางที่ประชุมห่วงสถานการณ์การเมือง คลุมเครือ หวั่นข้าราชการเกียร์ว่าง ด้านสภาธุรกิจตลาดทุน ขอนายกฯ เร่งตั้งตลาดหุ้น SME หวังช่วยกลุ่มธุรกิจรายย่อยเข้มแข็ง</p>,
#  <p>ผู้สื่อข่าวรายงานจากทำเนียบรัฐบาลว่า <strong>พล.อ.ประยุทธ์ จันทร์โอชา นายกรัฐมนตรี</strong> ได้เป็นประธานการประชุมหารือแนวทางการช่วยเหลือและฟื้นฟูเศรษฐกิจจากการแพร่ระบาดของโรคติดเชื้อไวรัสโคโรนา 2019 (โควิด-19) โดยมีวาระการหารือเรื่อง 1.รายงานสถานการณ์เศรษฐกิจ และกรอบการขับเคลื่อนเศรษฐกิจไทยในช่วงที่เหลือของปี 63 2. การช่วยเหลือและฟื้นฟูวิสาหกิจขนาดกลางและขนาดย่อม (SMEs) ที่ได้รับผลกระทบจาก Covid-19 โดยมีนายสมคิด จาตุศรีพิทักษ์ รองนายกรัฐมนตรี นายอุตตม สาวนายน รมว.คลัง และนายกอบศักดิ์ ภูตระกูล รองเลขาธิการนายกรัฐมนตรีฝ่ายการเมืองและเลขานุการคณะรัฐมนตรีฝ่ายเศรษฐกิจเข้าร่วม</p>,
#  <p>โดยนายกอบศักดิ์ เผยภายหลังการประชุมว่า นายกฯแจ้งว่าการประชุมทีมที่ปรึกษาเศรษฐกิจครั้งนี้เป็นรูปแบบใหม่ แบบนิว นอร์มอล ที่มีการหารือกับทุกภาคส่วน และจะนำข้อเสนอแนะไปพิจารณาประกอบดับข้อกฎหมายและงบประมาณ บางเรื่องจะส่งต่อให้กระทรวงที่เกี่ยวข้องนำเข้าที่ประชุมคณะรัฐมนตรี (ครม.) หรือบางเรื่องนำไปเข้า ครม.เศรษฐกิจก่อน โดยมีประเด็นสำคัญในครั้งนี้ ที่ภาคเอกชนเสนอให้รัฐบาล จัดตั้งศูนย์ฟื้นฟูเศรษฐกิจจากการระบาดของเชื้อไวรัสโคโรนา 2019 (โควิด-19) มีรูปแบบการปฏิบัติงานเช่นเดียวกันศูนย์บริหารสถานการณ์การแพร่ระบาดของโรคติดเชื้อไวรัสโคโรนา 2019 (ศบค.)ขึ้นมา เนื่องจากเห็นว่า ศบค.สามารถบริหารจัดการการแพร่ระบาดของโควิดได้ดี เป็นระบบและรวดเร็ว เพราะมีเอกภาพและบูรณาการ จึงควรนำวิธีบริหารจัดการมาใช้กับการฟื้นฟู เศรษฐกิจด้วย โดยให้นายกรัฐมนตรี เป็นประธาน</p>,
#  <p>“ที่ประชุมยังไม่ได้พูดถึงการเพิ่มเงินเยียวยา 5,000 บาท 3 เดือน ซึ่งจะหมดในเดือน ก.ค.นี้ แต่กำลังดูว่าเมื่อไม่มีเงินในกระเป๋าแล้ว รัฐบาลจะช่วยเหลือต่อได้อย่างไร โดยเฉพาะการช่วยธุรกิจเอสเอ็มอีให้มีสภาพคล่องมากขึ้นและยืนได้จนถึงปลายปี และยังเป็นห่วงบัณฑิตที่จบใหม่ในปีนี้ 500,000 รายจะตกงานหลายแสนคน”</p>,
#  <p>ขณะเดียวกัน มีภาคเอกชนเสนอให้รัฐบาลจัดทำและเปิดเผยข้อมูลทางเศรษฐกิจที่รวดเร็วทุกเดือน เพราะตอนนี้รอให้สภาพัฒนาการเศรษฐกิจและสังคมแห่งชาติ แถลงผลิตภัณฑ์มวลรวมในประเทศ (จีดีพี) ทุก 3 เดือนจะช้าเกินไป จึงขอให้ภาครัฐรวบรวมตัวเลขออกมาเปิดเผยในทุกๆเดือน ส่วนการแก้ปัญหาให้ธุรกิจขนาดกลางและขนาดย่อม (เอสเอ็มอี) ได้มีข้อเสนอหลายเรื่อง ซึ่งจะต้องนำมาจัดลำดับความสำคัญการแก้ปัญหา อาทิ การขยายเวลาพักชำระหนี้เงินต้นและดอกเบี้ย ที่จะสิ้นสุดวันที่ 22 ต.ค.นี้ ออกไปอีกระยะหนึ่ง</p>,
#  <p>การจัดตั้งกองทุนช่วยเหลือเอสเอ็มอีก วงเงิน 50,000 ล้านบาท จากเงินกู้เพื่อฟื้นฟูเศรษฐกิจและสังคม 400,000 ล้านบาท การแก้ปัญหาธนาคาร พาณิชย์ไม่ยอมปล่อยเงินกู้จากวงเงินสินเชื่อผ่อนปรนให้กับเอสเอ็มอี ดังจะเห็นได้จาก ธปท.ตั้งวงเงินไว้ 500,000 ล้านบาท แต่ปล่อยกู้จริง 100,000 ล้านบาท จึงมีข้อเสนอให้กู้ตามหลักเกณฑ์ ธปท.ที่ให้สินเชื่อ ดอกเบี้ย 2% ใน 2 ปีแรก จากนั้นในปีที่ 3-5 ขอให้ บรรษัทประกันสินเชื่ออุตสาหกรรมขนาดย่อม(บสย.) มาช่วยค้ำเงินกู้ในสัดส่วนที่มากขึ้น เพื่อให้ธนาคารกล้าปล่อยกู้ขึ้น ส่วนภาคท่องเที่ยวมีข้อเสนอส่งเสริมท่องเที่ยววันธรรมดา กระตุ้นท่องเที่ยวเมืองรอง การออกมาตรการชิม ช้อป ใช้ และการทำแพลตฟอร์มออนไลน์ของคนไทยสำหรับจองโรงแรม แทนที่จะไปเสียค่าธรรมเนียมสูงๆให้แพลตฟอร์มต่างประเทศ</p>,
างและขนาดย่อม (เอสเอ็มอี) ได้มีข้อเสนอหลายเรื่อง ซึ่งจะต้องนำมาจัดลำดับความสำคัญการแก้ปัญหา อาทิ การขยายเวลาพักชำระหนี้เงินต้นและดอกเบี้ย ที่จะสิ้นสุดวันที่ 22 ต.ค.นี้ ออกไปอีกระยะหนึ่งการจัดตั้งกองทุนช่วยเหลือเอสเอ็มอีก วงเงิน 50,000 ล้านบาท จากเงินกู้เพื่อฟื้นฟูเศรษฐกิจและสังคม 400,000 ล้านบาท การแก้ปัญหาธนาคาร พาณิชย์ไม่ยอมปล่อยเงินกู้จากวงเงินสินเชื่อผ่อนปรนให้กับเอสเอ็มอี ดังจะเห็นได้จาก ธปท.ตั้งวงเงินไว้ 500,000 ล้านบาท แต่ปล่อยกู้จริง 100,000 ล้านบาท จึงมีข้อเสนอให้กู้ตามหลักเกณฑ์ ธปท.ที่ให้สินเชื่อ ดอกเบี้ย 2% ใน 2 ปีแรก จากนั้นในปีที่ 3-5 ขอให้ บรรษัทประกันสินเชื่ออุตสาหกรรมขนาดย่อม(บสย.) มาช่วยค้ำเงินกู้ในสัดส่วนที่มากขึ้น เพื่อให้ธนาคารกล้าปล่อยกู้ขึ้น ส่วนภาคท่องเที่ยวมีข้อเสนอส่งเสริมท่องเที่ยววันธรรมดา กระตุ้นท่องเที่ยวเมืองรอง การออกมาตรการชิม ช้อป ใช้ และการทำแพลตฟอร์มออนไลน์ของคนไทยสำหรับจองโรงแรม แทนที่จะไปเสียค่าธรรมเนียมสูงๆให้แพลตฟอร์มต่างประเทศนายกลินท์ สารสิน ประธานสภาหอการค้าแห่งประเทศไทย กล่าวว่า เอกชนเป็นห่วงในเรื่องของสถานการณ์การเมืองที่ไม่แน่นอน ความคลุมเครือโดยเฉพาะการลาออกของ 4 กุมาร ที่แม้จะยังอยู่ในตำแหน่งรัฐมนตรี แต่ไม่ได้อยู่ในพรรคแล้ว อาจทำให้ข้าราชการเกียร์ว่าง ซึ่งเอกชนก็หารือใน ที่ประชุมโดยทางรองนายกฯสมคิด ก็ยืนยันว่ายังทำงานอยู่ ส่วนเรืองการปรับ ครม.นั้นเป็นเรื่องของนายกฯ ซึ่งเอกชนก็ต้องดูต่อไปว่าปรับออกมาเป็นอย่างไรนายไพบูลย์ นลินทรางกูร ประธานสภาธุรกิจตลาดทุนไทย เผยว่า ในส่วนของตลาดทุนได้ชี้แจงให้นายกฯรับทราบว่าขณะนี้ฝ่ายตลาดทุนได้เตรียมจัดตั้งตลาดหุ้น SME และสตาร์ตอัพ เพื่อช่วยเหลือธุรกิจ SME ในประเทศให้เข้มแข็ง จึงขอให้รัฐบาลเร่งให้ตลาดหุ้น SME เกิดขึ้นโดยเร็ว นอกจากนี้ยังได้เสนอและกระตุ้นให้รัฐบาล ยกระดับตลาด ทุนไทยให้เป็นศูนย์กลางตลาดทุนของอาเซียนอย่างจริงจัง เหมือนกับการผลักดันโครงการอีอีซี.'

# %%
for i, url in enumerate(news['url']):
    driver = webdriver.Chrome()
    driver.get(url)
    soup = BeautifulSoup(driver.page_source, 'lxml')

driver.close()
